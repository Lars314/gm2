# %%
import ROOT as r
# Out:
# Welcome to JupyROOT 6.18/04

# %%
file = r.TFile("quadrants.root", 'READ')

# %%
q1 = file.Get("calos_1-6_runall")

# %%
file.ls()
# Out:
# TFile**		quadrants.root
#  TFile*		quadrants.root
#   KEY: TH2D	calos_1-6_runall;1	y vs time
#   KEY: TH2D	calos_7-12_runall;1	y vs time
#   KEY: TH2D	calos_13-18_runall;1	y vs time
#   KEY: TH2D	calos_19-24_runall;1	y vs time

# %%
file2 = r.TFile("quadrants_groupA.root", "READ")
file2.ls()
# Out:
# TFile**		quadrants_groupA.root
#  TFile*		quadrants_groupA.root
#   KEY: TH2D	calos_1-6_runa;1	y vs time
#   KEY: TH2D	calos_7-12_runa;1	y vs time
#   KEY: TH2D	calos_13-18_runa;1	y vs time
#   KEY: TH2D	calos_19-24_runa;1	y vs time

# %%
file3 = r.TFile("quadrants_groupB.root", "READ")
file3.ls()
# Out:
# TFile**		quadrants_groupB.root
#  TFile*		quadrants_groupB.root
#   KEY: TH2D	calos_1-6_runb;1	y vs time
#   KEY: TH2D	calos_7-12_runb;1	y vs time
#   KEY: TH2D	calos_13-18_runb;1	y vs time
#   KEY: TH2D	calos_19-24_runb;1	y vs time

# %%
c=r.TCanvas()
q1.Draw()
c.Draw()

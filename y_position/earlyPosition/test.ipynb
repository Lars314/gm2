# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
import math
import numpy as np
import colorsys
from scipy import optimize as sciopt
import os
import lmfit
import uncertainties as u
import dataset as ds
import fit_functions as funcs
import importlib
# Out:
# Welcome to JupyROOT 6.18/04

# %%
plt.style.use(hep.style.ATLAS)
plt.style.use({"axes.labelsize":'36', 'lines.linewidth':'2', 'lines.markersize':'2', 'xtick.labelsize':'16'})

# %% [markdown]
# ### Set up the DataSet objects

# %%
importlib.reload(ds)
importlib.reload(funcs)
# Out:
# <module 'fit_functions' from '/home/lars/g-2/earlyPosition/fit_functions.py'>

# %%
energy_lim = [1000, 2400]

sixtyhour = ds.DataSet("1A", "60h", r.TFile("./60h.root"), energy_lim)
highkick  = ds.DataSet("1B", "HighKick", r.TFile("./highkick.root"), energy_lim)
nineday   = ds.DataSet("1C", "9day", r.TFile("./9day.root"), energy_lim)
endgame   = ds.DataSet("1D", "EndGame", r.TFile("./endgame.root"), energy_lim)
run2C     = ds.DataSet("2C", "run2C", r.TFile("./run2C.root"), energy_lim)

datasets = {"1A": sixtyhour, "1B":highkick, "1C":nineday, "1D":endgame, "2C": run2C}
#datasets = {"1D": endgame}


for name, dataset in datasets.items():
    dataset.set_up_calos(step_length=20, verbose=True)
# Out:
# Finished 1A calorimeter 1
# Finished 1A calorimeter 2
# Finished 1A calorimeter 3
# Finished 1A calorimeter 4
# Finished 1A calorimeter 5
# Finished 1A calorimeter 6
# Finished 1A calorimeter 7
# Finished 1A calorimeter 8
# Finished 1A calorimeter 9
# Finished 1A calorimeter 10
# Finished 1A calorimeter 11
# Finished 1A calorimeter 12
# Finished 1A calorimeter 13
# Finished 1A calorimeter 14
# Finished 1A calorimeter 15
# Finished 1A calorimeter 16
# Finished 1A calorimeter 17
# Finished 1A calorimeter 18
# Finished 1A calorimeter 19
# Finished 1A calorimeter 20
# Finished 1A calorimeter 21
# Finished 1A calorimeter 22
# Finished 1A calorimeter 23
# Finished 1A calorimeter 24
# Finished 1B calorimeter 1
# Finished 1B calorimeter 2
# Finished 1B calorimeter 3
# Finished 1B calorimeter 4
# Finished 1B calorimeter 5
# Finished 1B calorimeter 6
# Finished 1B calorimeter 7
# Finished 1B calorimeter 8
# Finished 1B calorimeter 9
# Finished 1B calorimeter 10
# Finished 1B calorimeter 11
# Finished 1B calorimeter 12
# Finished 1B calorimeter 13
# Finished 1B calorimeter 14
# Finished 1B calorimeter 15
# Finished 1B calorimeter 16
# Finished 1B calorimeter 17
# Finished 1B calorimeter 18
# Finished 1B calorimeter 19
# Finished 1B calorimeter 20
# Finished 1B calorimeter 21
# Finished 1B calorimeter 22
# Finished 1B calorimeter 23
# Finished 1B calorimeter 24
# Finished 1C calorimeter 1
# Finished 1C calorimeter 2
# Finished 1C calorimeter 3
# Finished 1C calorimeter 4
# Finished 1C calorimeter 5
# Finished 1C calorimeter 6
# Finished 1C calorimeter 7
# Finished 1C calorimeter 8
# Finished 1C calorimeter 9
# Finished 1C calorimeter 10
# Finished 1C calorimeter 11
# Finished 1C calorimeter 12
# Finished 1C calorimeter 13
# Finished 1C calorimeter 14
# Finished 1C calorimeter 15
# Finished 1C calorimeter 16
# Finished 1C calorimeter 17
# Finished 1C calorimeter 18
# Finished 1C calorimeter 19
# Finished 1C calorimeter 20
# Finished 1C calorimeter 21
# Finished 1C calorimeter 22
# Finished 1C calorimeter 23
# Finished 1C calorimeter 24
# Finished 1D calorimeter 1
# Finished 1D calorimeter 2
# Finished 1D calorimeter 3
# Finished 1D calorimeter 4
# Finished 1D calorimeter 5
# Finished 1D calorimeter 6
# Finished 1D calorimeter 7
# Finished 1D calorimeter 8
# Finished 1D calorimeter 9
# Finished 1D calorimeter 10
# Finished 1D calorimeter 11
# Finished 1D calorimeter 12
# Finished 1D calorimeter 13
# Finished 1D calorimeter 14
# Finished 1D calorimeter 15
# Finished 1D calorimeter 16
# Finished 1D calorimeter 17
# Finished 1D calorimeter 18
# Finished 1D calorimeter 19
# Finished 1D calorimeter 20
# Finished 1D calorimeter 21
# Finished 1D calorimeter 22
# Finished 1D calorimeter 23
# Finished 1D calorimeter 24
# Finished 2C calorimeter 1
# Finished 2C calorimeter 2
# Finished 2C calorimeter 3
# Finished 2C calorimeter 4
# Finished 2C calorimeter 5
# Finished 2C calorimeter 6
# Finished 2C calorimeter 7
# Finished 2C calorimeter 8
# Finished 2C calorimeter 9
# Finished 2C calorimeter 10
# Finished 2C calorimeter 11
# Finished 2C calorimeter 12
# Finished 2C calorimeter 13
# Finished 2C calorimeter 14
# Finished 2C calorimeter 15
# Finished 2C calorimeter 16
# Finished 2C calorimeter 17
# Finished 2C calorimeter 18
# Finished 2C calorimeter 19
# Finished 2C calorimeter 20
# Finished 2C calorimeter 21
# Finished 2C calorimeter 22
# Finished 2C calorimeter 23
# Finished 2C calorimeter 24

# %% [raw]
# hints = {
#     'c':    [-2.5, 2.5],
#     'a':    [0, 20],
#     'tauA': [4, 8],
#     'b':    [0, 10],
#     'tauB': [0, 500]
# }
#
# first_guess = {
#     'c':    0.68,
#     'a':    6.12,
#     'tauA': 6.05,
#     'b':    0.3,
#     'tauB': 100
# }
#
# rand_data = {}
# for name, dataset in datasets.items():
#     this_data = pd.DataFrame(columns = ['c', 'a', 'tauA', 'b', 'tauB', 'c_err', 'a_err', 'tauA_err', 'b_err', 'tauB_err', 'redchi', 'caloNum'])
#
#     for num, calo in dataset.calos.items():
#         for attempt in range(1, 11):
#             try:
#                 calo.build_params_2([10, 200], first_guess, hints)
#                 if(calo.func2_params['randomized'] == {}):
#                     first_guess = {'c':    0.68, 'a':    6.12, 'tauA': 6.05, 'b':    0.3, 'tauB': 100}
#                 else:
#                     first_guess = calo.func2_params['randomized']
#             except:
#                 print("The fit failed for {0} calo {1} on attempt {2}".format(name, num, attempt))
#                 first_guess = {'c':    0.68, 'a':    6.12, 'tauA': 6.05, 'b':    0.3, 'tauB': 100}
#
#         try:
#             p = calo.func2_params['randomized']
#             p['caloNum'] = num
#             this_data.loc[num] = p
#         except:
#             continue
#
#
#     rand_data[dataset.name] = this_data

# %%
rand_data = {}

# %%
"""
hints = {
    'c':    [-2.5, 2.5],
    'a':    [0, 20],
    'tauA': [4, 8],
    'b':    [0, 1],
    'tauB': [0, 100]
}
"""

hints = {
    #'c':    [-2.5, 2.5],
    'a':    [0, 9999],
    'tauA': [0, 9999],
    'b':    [0, 9999],
    'tauB': [0, 9999]
}

first_guess = {
    #'c':    0,
    'a':    3,
    'tauA': 5.79,
    'b':    3,
    'tauB': 8
}

#rand_data = {}

name = "2C"

this_data = pd.DataFrame(columns = ['a', 'tauA', 'b', 'tauB', 'a_err', 'tauA_err', 'b_err', 'tauB_err', 'redchi', 'caloNum'])

for num, calo in datasets[name].calos.items():
    first_guess = {'a':    3, 'tauA': 6, 'b':    3, 'tauB': 8}
    for attempt in range(1, 11):
        try:
            calo.build_params_2([10, 100], first_guess, hints)
            if(calo.func2_params['randomized'] == {}):
                first_guess = {'a':    3, 'tauA': 6, 'b':    3, 'tauB': 8}
            else:
                first_guess = calo.func2_params['randomized']
        except:
            print("The fit failed for {0} calo {1} on attempt {2}".format(name, num, attempt))
            first_guess = {'a':    3, 'tauA': 6, 'b':    3, 'tauB': 8}

    try:        
        p = calo.func2_params['randomized']
        p['caloNum'] = num
        this_data.loc[num] = p
    except:
        continue


    rand_data[name] = this_data
# Out:
# The fit failed for 2C calo 1 on attempt 1
# The fit failed for 2C calo 1 on attempt 2
# The fit failed for 2C calo 1 on attempt 3
# The fit failed for 2C calo 1 on attempt 4
# The fit failed for 2C calo 1 on attempt 5
# The fit failed for 2C calo 1 on attempt 6
# The fit failed for 2C calo 1 on attempt 7
# The fit failed for 2C calo 1 on attempt 8
# The fit failed for 2C calo 1 on attempt 9
# The fit failed for 2C calo 1 on attempt 10
# The fit failed for 2C calo 2 on attempt 1
# The fit failed for 2C calo 2 on attempt 2
# The fit failed for 2C calo 2 on attempt 3
# The fit failed for 2C calo 2 on attempt 4
# The fit failed for 2C calo 2 on attempt 5
# The fit failed for 2C calo 2 on attempt 6
# The fit failed for 2C calo 2 on attempt 7
# The fit failed for 2C calo 2 on attempt 8
# The fit failed for 2C calo 2 on attempt 9
# The fit failed for 2C calo 2 on attempt 10
# The fit failed for 2C calo 9 on attempt 1
# The fit failed for 2C calo 9 on attempt 2
# The fit failed for 2C calo 9 on attempt 3
# The fit failed for 2C calo 9 on attempt 4
# The fit failed for 2C calo 9 on attempt 5
# The fit failed for 2C calo 9 on attempt 6
# The fit failed for 2C calo 9 on attempt 7
# The fit failed for 2C calo 9 on attempt 8
# The fit failed for 2C calo 9 on attempt 9
# The fit failed for 2C calo 9 on attempt 10
# The fit failed for 2C calo 11 on attempt 1
# The fit failed for 2C calo 11 on attempt 2
# The fit failed for 2C calo 11 on attempt 3
# The fit failed for 2C calo 11 on attempt 4
# The fit failed for 2C calo 11 on attempt 5
# The fit failed for 2C calo 11 on attempt 6
# The fit failed for 2C calo 11 on attempt 7
# The fit failed for 2C calo 11 on attempt 8
# The fit failed for 2C calo 11 on attempt 9
# The fit failed for 2C calo 11 on attempt 10
# The fit failed for 2C calo 12 on attempt 1
# The fit failed for 2C calo 12 on attempt 2
# The fit failed for 2C calo 12 on attempt 3
# The fit failed for 2C calo 12 on attempt 4
# The fit failed for 2C calo 12 on attempt 5
# The fit failed for 2C calo 12 on attempt 6
# The fit failed for 2C calo 12 on attempt 7
# The fit failed for 2C calo 12 on attempt 8
# The fit failed for 2C calo 12 on attempt 9
# The fit failed for 2C calo 12 on attempt 10
# The fit failed for 2C calo 14 on attempt 1
# The fit failed for 2C calo 14 on attempt 2
# The fit failed for 2C calo 14 on attempt 3
# The fit failed for 2C calo 14 on attempt 4
# The fit failed for 2C calo 14 on attempt 5
# The fit failed for 2C calo 14 on attempt 6
# The fit failed for 2C calo 14 on attempt 7
# The fit failed for 2C calo 14 on attempt 8
# The fit failed for 2C calo 14 on attempt 9
# The fit failed for 2C calo 14 on attempt 10
# The fit failed for 2C calo 19 on attempt 1
# The fit failed for 2C calo 19 on attempt 2
# The fit failed for 2C calo 19 on attempt 3
# The fit failed for 2C calo 19 on attempt 4
# The fit failed for 2C calo 19 on attempt 5
# The fit failed for 2C calo 19 on attempt 6
# The fit failed for 2C calo 19 on attempt 7
# The fit failed for 2C calo 19 on attempt 8
# The fit failed for 2C calo 19 on attempt 9
# The fit failed for 2C calo 19 on attempt 10

# %%
fig, ax = plt.subplots(3,2)
fig.set_size_inches(20, 30)
"""
for name, df in rand_data.items():
    ax[0][0].plot(df['caloNum'], df['c'])
    ax[0][1].plot(df['caloNum'], df['a'])
    ax[1][0].plot(df['caloNum'], df['tauA'])
    ax[1][1].plot(df['caloNum'], df['b'])
    ax[2][0].plot(df['caloNum'], df['redchi'], label=name)
    ax[2][1].plot(df['caloNum'], df['tauB'])
"""

rand_data_2 = {}
rand_data_2['1A'] = rand_data['1A']
rand_data_2['1B'] = rand_data['1B']
rand_data_2['1C'] = rand_data['1C']
rand_data_2['1D'] = rand_data['1D']
#rand_data_2['2C'] = rand_data['2C']

for name, df in rand_data_2.items():
    #ax[0][0].errorbar(df['caloNum'], df['c'], yerr=df['c_err'])
    ax[0][1].errorbar(df['caloNum'], df['a'], yerr=df['a_err'])
    ax[1][0].errorbar(df['caloNum'], df['tauA'], yerr=df['tauA_err'])
    ax[1][1].errorbar(df['caloNum'], df['b'], yerr=df['b_err'])
    ax[2][1].plot(df['caloNum'], df['redchi'], label=name)
    ax[2][0].errorbar(df['caloNum'], df['tauB'], yerr=df['tauB_err'])
    
#ax[0][0].set_ylim(-0.5, 3.5)
ax[0][1].set_ylim(0, 10)
ax[2][0].set_ylim(-100, 7500)
ax[1][0].set_ylim(4, 10)
ax[1][1].set_ylim(0, 4)
ax[2][1].set_ylim(0, 2)

#ax[1][1].ticklabel_format(axis='y', style='sci', scilimits=(0,0))

ax[2][1].set_xlabel('calo number')
ax[2][0].set_xlabel('calo number')

#ax[2][1].set_yscale("log")

ax[0][0].set_ylabel('c    (mm)')
ax[0][1].set_ylabel('A    (mm)')
ax[2][1].set_ylabel(r'$chi^{2}$', fontsize=40)
ax[1][0].set_ylabel('τA    (μs)')
ax[2][0].set_ylabel('τB    (μs)')
ax[1][1].set_ylabel('B    (mm)')

fig.tight_layout()
fig.suptitle('With Randomization', fontsize=40, y=1.05)
ax[2][1].legend(loc=0, labelspacing=1.5, framealpha=1);
plt.savefig("func2_params_randomized", bbox_inches='tight')
plt.close()

# %% [markdown]
# ### fft

# %% [raw]
# fig, ax = plt.subplots(1,5)
# fig.set_size_inches(50, 10)
#
# for index, name in enumerate(datasets):
#
#     nora_sp = [0]*4304
#     rand_sp = [0]*4304
#
#     for caloNum in range(1,25):
#         calo = datasets[name].calos[caloNum]
#         calo.build_params_1(fit_lim=[10, 200])
#         calo.build_residuals_1()
#
#         nora_r_df = calo.func1_residuals['unrandomized']
#         rand_r_df = calo.func1_residuals['randomized']
#
#         nora_sp += np.fft.fft(nora_r_df['Residual'])
#         nora_freq = np.fft.fftfreq(len(nora_r_df['TimeBin']), (nora_r_df['TimeBin'][2]-nora_r_df['TimeBin'][1]) * 10**(-6))
#
#         rand_sp += np.fft.fft(rand_r_df['Residual'])
#         rand_freq = np.fft.fftfreq(len(rand_r_df['TimeBin']), (rand_r_df['TimeBin'][2]-rand_r_df['TimeBin'][1]) * 10**(-6))
#
#     nora_sp = nora_sp / 24
#     rand_sp = rand_sp / 24
#
#     nora_sp = np.log10(np.abs(nora_sp))
#     rand_sp = np.log10(np.abs(rand_sp))
#
#
#     ax[index].plot(np.abs(nora_freq) / (10**(6)), nora_sp, color='xkcd:blue', alpha=0.5, label='unrandomized');
#     ax[index].plot(np.abs(rand_freq) / (10**(6)), rand_sp, color='xkcd:red', alpha=0.5, label='randomized');
#
#     ax[index].legend(loc=0, fontsize='xx-large')
#     ax[index].set_ylim(-2, 4)
#     ax[index].set_xlabel('Frequency [MHz]', fontsize=32)
#     ax[index].set_title(name, fontsize=40)
#
#
#
# fig.suptitle('Log10 Scale', fontsize=40, y=1.05)
# plt.savefig('fft_average_log.png', bbox_inches='tight')
# plt.close()

# %% [raw]
# print(calo.data)

# %%
calo = datasets['1B'].calos[12]

df = calo.data['randomized']
params = calo.func2_params['randomized']

time = np.linspace(fit_lim[0],fit_lim[1],1000)
fit = funcs.func2(t=time, a=params['a'], tauA=params['tauA'], b=params['b'], tauB=params['tauB'])

fig, ax = plt.subplots(1,1)
fig.set_size_inches(20,10)

ax.plot(df['TimeBin'], df['Mean'], linestyle='none', marker='o', markersize=2, label='data')
ax.plot(time, fit, label='fit')

ax.legend(loc=0)
#ax.set_xlim(0, 300)

print(calo.func2_result['randomized'].fit_report())
# Out:
# [[Model]]
#     Model(func2)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 14
#     # data points      = 102
#     # variables        = 4
#     chi-square         = 299.552241
#     reduced chi-square = 3.05665552
#     Akaike info crit   = 117.886234
#     Bayesian info crit = 128.386125
# [[Variables]]
#     a:     7.81505104 +/- 10929876.7 (139856754.00%) (init = 7.815051)
#     tauA:  5.48173272 +/- 2509.29689 (45775.62%) (init = 5.481733)
#     b:     0.99398672 +/- 10929873.7 (1099599569.77%) (init = 0.9939867)
#     tauB:  5.48213330 +/- 19674.5966 (358885.78%) (init = 5.482133)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a, b)       =  1.000
#     C(tauA, tauB) =  0.975
#     C(tauA, b)    =  0.123
#     C(a, tauA)    =  0.123
#     C(a, tauB)    = -0.101
#     C(b, tauB)    = -0.101

# %%
model = lmfit.Model(funcs.func2)
fit_lim = [10, 200]

df = datasets['1B'].calos[12].data['randomized']
fit_data = df[(df['TimeBin'] > fit_lim[0]) & (df['TimeBin'] < fit_lim[1]) ][:]


#model.set_param_hint('c', min=-2.5, max=2.5)
model.set_param_hint('a', min=0, max=1000)
model.set_param_hint('tauA', min=0, max=10000)
model.set_param_hint('b', min=0, max=1000)
model.set_param_hint('tauB', min=0, max=40000)


result = model.fit(fit_data['Mean'], t=fit_data['TimeBin'],
                   a=6.53, tauA=5.79, b=0, tauB=2,
                   weights=1/fit_data['MeanError'])
#cov = result.covar

time = np.linspace(fit_lim[0],fit_lim[1],100)
guess = funcs.func2(t=time, a=5.8, tauA=5.79, b=0, tauB=2)

fig, ax = plt.subplots(1,1)
fig.set_size_inches(20,10)

ax.plot(df['TimeBin'], df['Mean'], linestyle='none', marker='o', markersize=2, label='data')
ax.plot(fit_data['TimeBin'], result.best_fit, label='fit')
ax.plot(time, guess, label='guess')

ax.legend(loc=0)

print(result.fit_report())
# Out:
# [[Model]]
#     Model(func2)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 216
#     # variables        = 4
#     chi-square         = 1089.85247
#     reduced chi-square = 5.14081355
#     Akaike info crit   = 357.600150
#     Bayesian info crit = 371.101263
# ##  Warning: uncertainties could not be estimated:
#     a:     at initial value
#     tauA:  at initial value
#     b:     at boundary
#     tauB:  at initial value
# [[Variables]]
#     a:     6.53000000 (init = 6.53)
#     tauA:  5.79000000 (init = 5.79)
#     b:     0.00000000 (init = 0)
#     tauB:  2.00000000 (init = 2)

# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
import math
import numpy as np
import colorsys
from scipy import optimize as sciopt
import os
import lmfit
# Out:
# Welcome to JupyROOT 6.18/04

# %%
plt.style.use(hep.style.ATLAS)
plt.style.use({"axes.labelsize":'36', 'lines.linewidth':'2', 'lines.markersize':'2'})

# %%
R1D = pd.read_csv("endgame.csv")
R1A = pd.read_csv("60h.csv")
R1C = pd.read_csv("9day.csv")
R1B = pd.read_csv("highkick.csv")
R2C = pd.read_csv("run2C.csv")

# %%
a_data = pd.DataFrame(columns = ["caloNum", "R1A", "R1A_err", "rand_R1A", "rand_R1A_err",
                                "R1B", "R1B_err", "rand_R1B", "rand_R1B_err",
                                "R1C", "R1C_err", "rand_R1C", "rand_R1C_err",
                                "R1D", "R1D_err", "rand_R1D", "rand_R1D_err",
                                "R2C", "R2C_err", "rand_R2C", "rand_R2C_err"])
c_data = pd.DataFrame(columns = ["caloNum", "R1A", "R1A_err", "rand_R1A", "rand_R1A_err",
                                "R1B", "R1B_err", "rand_R1B", "rand_R1B_err",
                                "R1C", "R1C_err", "rand_R1C", "rand_R1C_err",
                                "R1D", "R1D_err", "rand_R1D", "rand_R1D_err",
                                "R2C", "R2C_err", "rand_R2C", "rand_R2C_err"])
t_data = pd.DataFrame(columns = ["caloNum", "R1A", "R1A_err", "rand_R1A", "rand_R1A_err",
                                "R1B", "R1B_err", "rand_R1B", "rand_R1B_err",
                                "R1C", "R1C_err", "rand_R1C", "rand_R1C_err",
                                "R1D", "R1D_err", "rand_R1D", "rand_R1D_err",
                                "R2C", "R2C_err", "rand_R2C", "rand_R2C_err"])
m_data = pd.DataFrame(columns = ["caloNum", "R1A", "R1A_err", "rand_R1A", "rand_R1A_err",
                                "R1B", "R1B_err", "rand_R1B", "rand_R1B_err",
                                "R1C", "R1C_err", "rand_R1C", "rand_R1C_err",
                                "R1D", "R1D_err", "rand_R1D", "rand_R1D_err",
                                "R2C", "R2C_err", "rand_R2C", "rand_R2C_err"])

chisqr_data = pd.DataFrame(columns = ['R1A', 'R1B', 'R1C', 'R1D', 'R2C',
                                      'rand_R1A', 'rand_R1B', 'rand_R1C', 'rand_R1D', 'rand_R2C',
                                      'caloNum'])

for num in range(0, 24):
    
    chi = {'R1A':R1A.loc[num]['chisqr'],
           'R1B':R1B.loc[num]['chisqr'],
           'R1C':R1C.loc[num]['chisqr'],
           'R1D':R1D.loc[num]['chisqr'],
           'R2C':R2C.loc[num]['chisqr'],
           'rand_R1A':R1A.loc[num]['rand_chisqr'],
           'rand_R1B':R1B.loc[num]['rand_chisqr'],
           'rand_R1C':R1C.loc[num]['rand_chisqr'],
           'rand_R1D':R1D.loc[num]['rand_chisqr'],
           'rand_R2C':R2C.loc[num]['rand_chisqr'],
           'caloNum':R1D.loc[num]['caloNum']}
    
    roA = {"caloNum":R1D.loc[num]['caloNum'],
           "R1A":R1A.loc[num]['a'],
           "R1A_err":R1A.loc[num]['a_err'],
           "rand_R1A":R1A.loc[num]['rand_a'],
           "rand_R1A_err":R1A.loc[num]['rand_a_err'],
           "R1B":R1B.loc[num]['a'],
           "R1B_err":R1B.loc[num]['a_err'],
           "rand_R1B":R1B.loc[num]['rand_a'],
           "rand_R1B_err":R1B.loc[num]['rand_a_err'],
           "R1C":R1C.loc[num]['a'],
           "R1C_err":R1C.loc[num]['a_err'],
           "rand_R1C":R1C.loc[num]['rand_a'],
           "rand_R1C_err":R1C.loc[num]['rand_a_err'],
           "R1D":R1D.loc[num]['a'],
           "R1D_err":R1D.loc[num]['a_err'],
           "rand_R1D":R1D.loc[num]['rand_a'],
           "rand_R1D_err":R1D.loc[num]['rand_a_err'],
           "R2C":R2C.loc[num]['a'],
           "R2C_err":R2C.loc[num]['a_err'],
           "rand_R2C":R2C.loc[num]['rand_a'],
           "rand_R2C_err":R2C.loc[num]['rand_a_err']}
    
    roC = {"caloNum":R1D.loc[num]['caloNum'],
           "R1A":R1A.loc[num]['c'],
           "R1A_err":R1A.loc[num]['c_err'],
           "rand_R1A":R1A.loc[num]['rand_c'],
           "rand_R1A_err":R1A.loc[num]['rand_c_err'],
           "R1B":R1B.loc[num]['c'],
           "R1B_err":R1B.loc[num]['c_err'],
           "rand_R1B":R1B.loc[num]['rand_c'],
           "rand_R1B_err":R1B.loc[num]['rand_c_err'],
           "R1C":R1C.loc[num]['c'],
           "R1C_err":R1C.loc[num]['c_err'],
           "rand_R1C":R1C.loc[num]['rand_c'],
           "rand_R1C_err":R1C.loc[num]['rand_c_err'],
           "R1D":R1D.loc[num]['c'],
           "R1D_err":R1D.loc[num]['c_err'],
           "rand_R1D":R1D.loc[num]['rand_c'],
           "rand_R1D_err":R1D.loc[num]['rand_c_err'],
           "R2C":R2C.loc[num]['c'],
           "R2C_err":R2C.loc[num]['c_err'],
           "rand_R2C":R2C.loc[num]['rand_c'],
           "rand_R2C_err":R2C.loc[num]['rand_c_err']}
    
    roT = {"caloNum":R1D.loc[num]['caloNum'],
           "R1A":R1A.loc[num]['t'],
           "R1A_err":R1A.loc[num]['t_err'],
           "rand_R1A":R1A.loc[num]['rand_t'],
           "rand_R1A_err":R1A.loc[num]['rand_t_err'],
           "R1B":R1B.loc[num]['t'],
           "R1B_err":R1B.loc[num]['t_err'],
           "rand_R1B":R1B.loc[num]['rand_t'],
           "rand_R1B_err":R1B.loc[num]['rand_t_err'],
           "R1C":R1C.loc[num]['t'],
           "R1C_err":R1C.loc[num]['t_err'],
           "rand_R1C":R1C.loc[num]['rand_t'],
           "rand_R1C_err":R1C.loc[num]['rand_t_err'],
           "R1D":R1D.loc[num]['t'],
           "R1D_err":R1D.loc[num]['t_err'],
           "rand_R1D":R1D.loc[num]['rand_t'],
           "rand_R1D_err":R1D.loc[num]['rand_t_err'],
           "R2C":R2C.loc[num]['t'],
           "R2C_err":R2C.loc[num]['t_err'],
           "rand_R2C":R2C.loc[num]['rand_t'],
           "rand_R2C_err":R2C.loc[num]['rand_t_err']}
    
    roM = {"caloNum":R1D.loc[num]['caloNum'],
           "R1A":R1A.loc[num]['m'],
           "R1A_err":R1A.loc[num]['m_err'],
           "rand_R1A":R1A.loc[num]['rand_m'],
           "rand_R1A_err":R1A.loc[num]['rand_m_err'],
           "R1B":R1B.loc[num]['m'],
           "R1B_err":R1B.loc[num]['m_err'],
           "rand_R1B":R1B.loc[num]['rand_m'],
           "rand_R1B_err":R1B.loc[num]['rand_m_err'],
           "R1C":R1C.loc[num]['m'],
           "R1C_err":R1C.loc[num]['m_err'],
           "rand_R1C":R1C.loc[num]['rand_m'],
           "rand_R1C_err":R1C.loc[num]['rand_m_err'],
           "R1D":R1D.loc[num]['m'],
           "R1D_err":R1D.loc[num]['m_err'],
           "rand_R1D":R1D.loc[num]['rand_m'],
           "rand_R1D_err":R1D.loc[num]['rand_m_err'],
           "R2C":R2C.loc[num]['m'],
           "R2C_err":R2C.loc[num]['m_err'],
           "rand_R2C":R2C.loc[num]['rand_m'],
           "rand_R2C_err":R2C.loc[num]['rand_m_err']}

    t_data.loc[num] = roT
    c_data.loc[num] = roC
    a_data.loc[num] = roA
    m_data.loc[num] = roM
    chisqr_data.loc[num] = chi

# %%
def plot_per_ds():

    fig, ax = plt.subplots(3,2)
    fig.set_size_inches(20,30)
    
    #------------Plotting--------------------------------------------

    ax[0][0].plot(c_data['caloNum'], c_data['R1A'], label='1A', color='C0')
    ax[0][0].plot(c_data['caloNum'], c_data['R1B'], label='1B', color='C1')
    ax[0][0].plot(c_data['caloNum'], c_data['R1C'], label='1C', color='C2')
    ax[0][0].plot(c_data['caloNum'], c_data['R1D'], label='1D', color='C3')
    ax[0][0].plot(c_data['caloNum'], c_data['R2C'], label='2C', color='C4')
    
    ax[0][1].plot(a_data['caloNum'], a_data['R1A'], label='60h', color='C0')
    ax[0][1].plot(a_data['caloNum'], a_data['R1B'], label='highkick', color='C1')
    ax[0][1].plot(a_data['caloNum'], a_data['R1C'], label='9day', color='C2')
    ax[0][1].plot(a_data['caloNum'], a_data['R1D'], label='endgame', color='C3')
    ax[0][1].plot(a_data['caloNum'], a_data['R2C'], label='run2C', color='C4')
    
    ax[1][0].plot(t_data['caloNum'], t_data['R1A'], label='60h', color='C0')
    ax[1][0].plot(t_data['caloNum'], t_data['R1B'], label='highkick', color='C1')
    ax[1][0].plot(t_data['caloNum'], t_data['R1C'], label='9day', color='C2')
    ax[1][0].plot(t_data['caloNum'], t_data['R1D'], label='endgame', color='C3')
    ax[1][0].plot(t_data['caloNum'], t_data['R2C'], label='run2C', color='C4')
    
    ax[1][1].plot(m_data['caloNum'], m_data['R1A'], label='60h', color='C0')
    ax[1][1].plot(m_data['caloNum'], m_data['R1B'], label='highkick', color='C1')
    ax[1][1].plot(m_data['caloNum'], m_data['R1C'], label='9day', color='C2')
    ax[1][1].plot(m_data['caloNum'], m_data['R1D'], label='endgame', color='C3')
    ax[1][1].plot(m_data['caloNum'], m_data['R2C'], label='run2C', color='C4')
    
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['R1A'], label='60h', color='C0')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['R1B'], label='highkick', color='C1')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['R1C'], label='9day', color='C2')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['R1D'], label='endgame', color='C3')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['R2C'], label='run2C', color='C4')
    
    ax[2][1].axis('off')
    
    ax[0][0].errorbar(c_data['caloNum'], c_data['R1A'], yerr=c_data['R1A_err'], color='C0', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['R1B'], yerr=c_data['R1B_err'], color='C1', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['R1C'], yerr=c_data['R1C_err'], color='C2', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['R1D'], yerr=c_data['R1D_err'], color='C3', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['R2C'], yerr=c_data['R2C_err'], color='C4', elinewidth=2)
    
    ax[0][1].errorbar(a_data['caloNum'], a_data['R1A'], yerr=a_data['R1A_err'], color='C0', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['R1B'], yerr=a_data['R1B_err'], color='C1', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['R1C'], yerr=a_data['R1C_err'], color='C2', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['R1D'], yerr=a_data['R1D_err'], color='C3', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['R2C'], yerr=a_data['R2C_err'], color='C4', elinewidth=2)
    
    ax[1][0].errorbar(t_data['caloNum'], t_data['R1A'], yerr=t_data['R1A_err'], color='C0', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['R1B'], yerr=t_data['R1B_err'], color='C1', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['R1C'], yerr=t_data['R1C_err'], color='C2', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['R1D'], yerr=t_data['R1D_err'], color='C3', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['R2C'], yerr=t_data['R2C_err'], color='C4', elinewidth=2)
    
    ax[1][1].errorbar(m_data['caloNum'], m_data['R1A'], yerr=m_data['R1A_err'], color='C0', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['R1B'], yerr=m_data['R1B_err'], color='C1', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['R1C'], yerr=m_data['R1C_err'], color='C2', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['R1D'], yerr=m_data['R1D_err'], color='C3', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['R2C'], yerr=m_data['R2C_err'], color='C4', elinewidth=2)
    
    
    #------------Labelling--------------------------------------------

    
    
    ax[1][1].ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    
    ax[0][0].set_xlabel('calo number')
    ax[0][1].set_xlabel('calo number')
    ax[2][0].set_xlabel('calo number')
    ax[1][0].set_xlabel('calo number')
    ax[1][1].set_xlabel('calo number')
    
    ax[0][0].set_ylabel('c    (mm)')
    ax[0][1].set_ylabel('A    (mm)')
    ax[2][0].set_ylabel(r'$chi^{2}$', fontsize=40)
    ax[1][0].set_ylabel('τ    (μs)')
    ax[1][1].set_ylabel('m    (mm/μs)')
    
    ax[0][0].set_ylim(-0.5, 3.5)
    ax[0][1].set_ylim(0, 20)
    ax[2][0].set_ylim(0, 17)
    ax[1][0].set_ylim(0, 23)
    ax[1][1].set_ylim(-0.00225, 0.001)
    
    fig.tight_layout()
    fig.suptitle('Without Randomization', fontsize=40, y=1.05)
    ax[0][0].legend(loc=(1.5, -2), fontsize='x-large', labelspacing=1.5, framealpha=1);
    
    
    plt.savefig('without randomization.png', bbox_inches='tight');
    plt.close()

    
    fig, ax = plt.subplots(3,2)
    fig.set_size_inches(20,30)
    
    #------------Plotting--------------------------------------------

    ax[0][0].plot(c_data['caloNum'], c_data['rand_R1A'], linewidth=2, label='1A', color='C0')
    ax[0][0].plot(c_data['caloNum'], c_data['rand_R1B'], linewidth=2, label='1B', color='C1')
    ax[0][0].plot(c_data['caloNum'], c_data['rand_R1C'], linewidth=2, label='1C', color='C2')
    ax[0][0].plot(c_data['caloNum'], c_data['rand_R1D'], linewidth=2, label='1D', color='C3')
    ax[0][0].plot(c_data['caloNum'], c_data['rand_R2C'], linewidth=2, label='2C', color='C4')
    
    ax[0][1].plot(a_data['caloNum'], a_data['rand_R1A'], linewidth=2, label='60h', color='C0')
    ax[0][1].plot(a_data['caloNum'], a_data['rand_R1B'], linewidth=2, label='highkick', color='C1')
    ax[0][1].plot(a_data['caloNum'], a_data['rand_R1C'], linewidth=2, label='9day', color='C2')
    ax[0][1].plot(a_data['caloNum'], a_data['rand_R1D'], linewidth=2, label='endgame', color='C3')
    ax[0][1].plot(a_data['caloNum'], a_data['rand_R2C'], linewidth=2, label='run2C', color='C4')
    
    ax[1][0].plot(t_data['caloNum'], t_data['rand_R1A'], linewidth=2, label='60h', color='C0')
    ax[1][0].plot(t_data['caloNum'], t_data['rand_R1B'], linewidth=2, label='highkick', color='C1')
    ax[1][0].plot(t_data['caloNum'], t_data['rand_R1C'], linewidth=2, label='9day', color='C2')
    ax[1][0].plot(t_data['caloNum'], t_data['rand_R1D'], linewidth=2, label='endgame', color='C3')
    ax[1][0].plot(t_data['caloNum'], t_data['rand_R2C'], linewidth=2, label='run2C', color='C4')
    
    ax[1][1].plot(m_data['caloNum'], m_data['rand_R1A'], linewidth=2, label='60h', color='C0')
    ax[1][1].plot(m_data['caloNum'], m_data['rand_R1B'], linewidth=2, label='highkick', color='C1')
    ax[1][1].plot(m_data['caloNum'], m_data['rand_R1C'], linewidth=2, label='9day', color='C2')
    ax[1][1].plot(m_data['caloNum'], m_data['rand_R1D'], linewidth=2, label='endgame', color='C3')
    ax[1][1].plot(m_data['caloNum'], m_data['rand_R2C'], linewidth=2, label='run2C', color='C4')
    
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['rand_R1A'], linewidth=2, label='60h', color='C0')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['rand_R1B'], linewidth=2, label='highkick', color='C1')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['rand_R1C'], linewidth=2, label='9day', color='C2')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['rand_R1D'], linewidth=2, label='endgame', color='C3')
    ax[2][0].plot(chisqr_data['caloNum'], chisqr_data['rand_R2C'], linewidth=2, label='run2C', color='C4')
    
    ax[2][1].axis('off')
    
    ax[0][0].errorbar(c_data['caloNum'], c_data['rand_R1A'], yerr=c_data['rand_R1A_err'], color='C0', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['rand_R1B'], yerr=c_data['rand_R1B_err'], color='C1', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['rand_R1C'], yerr=c_data['rand_R1C_err'], color='C2', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['rand_R1D'], yerr=c_data['rand_R1D_err'], color='C3', elinewidth=2)
    ax[0][0].errorbar(c_data['caloNum'], c_data['rand_R2C'], yerr=c_data['rand_R2C_err'], color='C4', elinewidth=2)
    
    ax[0][1].errorbar(a_data['caloNum'], a_data['rand_R1A'], yerr=a_data['rand_R1A_err'], color='C0', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['rand_R1B'], yerr=a_data['rand_R1B_err'], color='C1', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['rand_R1C'], yerr=a_data['rand_R1C_err'], color='C2', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['rand_R1D'], yerr=a_data['rand_R1D_err'], color='C3', elinewidth=2)
    ax[0][1].errorbar(a_data['caloNum'], a_data['rand_R2C'], yerr=a_data['rand_R2C_err'], color='C4', elinewidth=2)
    
    ax[1][0].errorbar(t_data['caloNum'], t_data['rand_R1A'], yerr=t_data['rand_R1A_err'], color='C0', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['rand_R1B'], yerr=t_data['rand_R1B_err'], color='C1', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['rand_R1C'], yerr=t_data['rand_R1C_err'], color='C2', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['rand_R1D'], yerr=t_data['rand_R1D_err'], color='C3', elinewidth=2)
    ax[1][0].errorbar(t_data['caloNum'], t_data['rand_R2C'], yerr=t_data['rand_R2C_err'], color='C4', elinewidth=2)
    
    ax[1][1].errorbar(m_data['caloNum'], m_data['rand_R1A'], yerr=m_data['rand_R1A_err'], color='C0', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['rand_R1B'], yerr=m_data['rand_R1B_err'], color='C1', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['rand_R1C'], yerr=m_data['rand_R1C_err'], color='C2', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['rand_R1D'], yerr=m_data['rand_R1D_err'], color='C3', elinewidth=2)
    ax[1][1].errorbar(m_data['caloNum'], m_data['rand_R2C'], yerr=m_data['rand_R2C_err'], color='C4', elinewidth=2)
    
    
    #------------Labelling--------------------------------------------
    
    ax[1][1].ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    
    ax[0][0].set_xlabel('calo number')
    ax[0][1].set_xlabel('calo number')
    ax[2][0].set_xlabel('calo number')
    ax[1][0].set_xlabel('calo number')
    ax[1][1].set_xlabel('calo number')
    
    ax[0][0].set_ylabel('c    (mm)')
    ax[0][1].set_ylabel('A    (mm)')
    ax[2][0].set_ylabel(r'$chi^{2}$', fontsize=40)
    ax[1][0].set_ylabel('τ    (μs)')
    ax[1][1].set_ylabel('m    (mm/μs)')
    
    ax[0][0].set_ylim(-0.5, 3.5)
    ax[0][1].set_ylim(0, 20)
    ax[2][0].set_ylim(0, 17)
    ax[1][0].set_ylim(0, 23)
    ax[1][1].set_ylim(-0.00225, 0.001)
    
    
    fig.tight_layout()
    fig.suptitle('With Randomization', fontsize=40, y=1.05)
    ax[0][0].legend(loc=(1.5, -2), fontsize='x-large', labelspacing=1.5, framealpha=1);

    plt.savefig('with randomization.png', bbox_inches='tight');
    plt.close()

# %%
plot_per_ds()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

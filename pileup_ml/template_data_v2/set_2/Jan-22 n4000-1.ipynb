# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as skl
import pickle
import spliland
import importlib
import random
import fclParse
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# Welcome to JupyROOT 6.18/04

# %%
directory = './template_data_v2/set_2/'

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Intro
#
# The purpose of this notebook is to make a second attempt at a neural network, following along with what was described in the paper "Deep Learning Based Pulse Shape Analysis for GERDA" by Philipp Holl in 2017. This algorithm consists of an autoencoder, decoder, and then classifier.
#
# I am also following this guide: https://keras.io/examples/timeseries/timeseries_anomaly_detection/ for the implementation of the layers described in the paper into python

# %% [markdown]
# ### Prep the data

# %%
n_points = 4000

with open(directory + 'x.data', 'rb') as xFile:
    biggestX = pickle.load(xFile)
    x_train = []
    x_test = []
    for x in biggestX[:n_points]:
        x_train.append(x)
    for x in biggestX[n_points:n_points+500]:
        x_test.append(x)
    xFile.close()

with open(directory + 'y.data', 'rb') as yFile:
    biggestY = pickle.load(yFile)
    y_train = biggestY[:n_points]
    y_test = biggestY[n_points:n_points+500]
    yFile.close()
    
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = np.reshape(x_train, (n_points, 21816, 1))
Y_train = np.reshape(y_train, (n_points, 1))

# %%
X_train.shape
# Out:
# (4000, 21816, 1)

# %% [markdown]
# ### Classifier

# %%
classifier_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(21816,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu')
])

# %%
classifier_model.compile(optimizer = 'adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (4000, 21816, 1)
# (4000, 1)

# %%
classifier_history = classifier_model.fit(X_train,
                                          Y_train,
                                          epochs=50)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 6s 48ms/step - loss: 2.3660 - accuracy: 0.3265
# Epoch 2/50
# 125/125 [==============================] - 6s 48ms/step - loss: 1.8664 - accuracy: 0.4640
# Epoch 3/50
# 125/125 [==============================] - 6s 48ms/step - loss: 1.6893 - accuracy: 0.5320
# Epoch 4/50
# 125/125 [==============================] - 6s 48ms/step - loss: 1.5463 - accuracy: 0.5922
# Epoch 5/50
# 125/125 [==============================] - 6s 48ms/step - loss: 1.4337 - accuracy: 0.6340
# Epoch 6/50
# 125/125 [==============================] - 6s 48ms/step - loss: 1.3033 - accuracy: 0.6597
# Epoch 7/50
# 125/125 [==============================] - 6s 49ms/step - loss: 1.2158 - accuracy: 0.6793
# Epoch 8/50
# 125/125 [==============================] - 6s 50ms/step - loss: 1.1079 - accuracy: 0.6963
# Epoch 9/50
# 125/125 [==============================] - 6s 49ms/step - loss: 1.0283 - accuracy: 0.7020
# Epoch 10/50
# 125/125 [==============================] - 6s 49ms/step - loss: 1.0253 - accuracy: 0.7053
# Epoch 11/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.9880 - accuracy: 0.7097
# Epoch 12/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.9420 - accuracy: 0.7147
# Epoch 13/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.9197 - accuracy: 0.7170
# Epoch 14/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.9100 - accuracy: 0.7172
# Epoch 15/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.9164 - accuracy: 0.7145
# Epoch 16/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8875 - accuracy: 0.7218
# Epoch 17/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8795 - accuracy: 0.7228
# Epoch 18/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.8586 - accuracy: 0.7240
# Epoch 19/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8666 - accuracy: 0.7253
# Epoch 20/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8686 - accuracy: 0.7230
# Epoch 21/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8452 - accuracy: 0.7278
# Epoch 22/50
# 125/125 [==============================] - 7s 52ms/step - loss: 0.8967 - accuracy: 0.7203
# Epoch 23/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.9082 - accuracy: 0.7200
# Epoch 24/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8700 - accuracy: 0.7247
# Epoch 25/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8481 - accuracy: 0.7260
# Epoch 26/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.9063 - accuracy: 0.7203
# Epoch 27/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8966 - accuracy: 0.7207
# Epoch 28/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8473 - accuracy: 0.7270
# Epoch 29/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.8374 - accuracy: 0.7285
# Epoch 30/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.8506 - accuracy: 0.7260
# Epoch 31/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8313 - accuracy: 0.7297
# Epoch 32/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.8540 - accuracy: 0.7245
# Epoch 33/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8379 - accuracy: 0.7283
# Epoch 34/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.8612 - accuracy: 0.7240
# Epoch 35/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.8723 - accuracy: 0.7230
# Epoch 36/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.8523 - accuracy: 0.7253
# Epoch 37/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.9103 - accuracy: 0.7178
# Epoch 38/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8673 - accuracy: 0.7218
# Epoch 39/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8507 - accuracy: 0.7270
# Epoch 40/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8365 - accuracy: 0.7290
# Epoch 41/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8320 - accuracy: 0.7283
# Epoch 42/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8544 - accuracy: 0.7253
# Epoch 43/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.8408 - accuracy: 0.7285
# Epoch 44/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8540 - accuracy: 0.7280
# Epoch 45/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8326 - accuracy: 0.7300
# Epoch 46/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8430 - accuracy: 0.7268
# Epoch 47/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.8374 - accuracy: 0.7275
# Epoch 48/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8297 - accuracy: 0.7283
# Epoch 49/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.8240 - accuracy: 0.7300
# Epoch 50/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.8446 - accuracy: 0.7287

# %% [markdown]
# ### Performance Stats

# %%
fig, ax = plt.subplots(1,2);
fig.set_size_inches(14,7);

ax[0].plot(classifier_history.history['accuracy'])

ax[0].set_xlabel("epoch", fontsize=20)
ax[0].set_ylabel("accuracy %", fontsize=20)
ax[0].legend()

ax[1].plot(classifier_history.history['loss'])

ax[1].set_xlabel("epoch", fontsize=20)
ax[1].set_ylabel("training loss", fontsize=20)
ax[1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
Y_pred = classifier_model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

matrix = confusion_matrix(y_test, y_pred, normalize='true', labels=[0,1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

labels = ['0', '1', '2', '3', '4', '5', '6']

grid = np.array(matrix)
im = ax.imshow(grid)

for k in range (0, len(grid)):
        for l in range (0, len(grid[0])):
            ax.text(l-0.3, k+0.1, str(grid[k][l])[:4], size=20, color='white')
            
ax.set_xticklabels([''] + labels);
ax.set_yticklabels([''] + labels);

ax.set_ylabel('True Pulse Number', fontsize=20);
ax.set_xlabel('Classified Pulse Number', fontsize=20);

#ax.set_title("with autoencoder", fontsize=20)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_test, alpha=0.5, label='True Pulse Number')
ax.hist(y_pred, alpha=0.5, label='Classified Pulse Number')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_train, alpha=0.5, label='y train')
ax.hist(y_test, alpha=0.5, label='y test')
ax.legend()

# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as skl
import pickle
import spliland
import importlib
import random
import fclParse
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# Welcome to JupyROOT 6.18/04

# %%
directory = './template_data_v2/set_2/'

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Intro
#
# The purpose of this notebook is to make a second attempt at a neural network, following along with what was described in the paper "Deep Learning Based Pulse Shape Analysis for GERDA" by Philipp Holl in 2017. This algorithm consists of an autoencoder, decoder, and then classifier.
#
# I am also following this guide: https://keras.io/examples/timeseries/timeseries_anomaly_detection/ for the implementation of the layers described in the paper into python

# %% [markdown]
# ### Prep the data

# %%
n_points = 2500

with open(directory + 'x.data', 'rb') as xFile:
    biggestX = pickle.load(xFile)
    x_train = []
    x_test = []
    for x in biggestX[:n_points]:
        x_train.append(x)
    for x in biggestX[n_points:n_points+500]:
        x_test.append(x)
    xFile.close()

with open(directory + 'y.data', 'rb') as yFile:
    biggestY = pickle.load(yFile)
    y_train = biggestY[:n_points]
    y_test = biggestY[n_points:n_points+500]
    yFile.close()
    
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = np.reshape(x_train, (n_points, 21816, 1))
Y_train = np.reshape(y_train, (n_points, 1))

# %%
X_train.shape
# Out:
# (2500, 21816, 1)

# %% [markdown]
# ### Classifier

# %%
classifier_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(21816,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu')
])

# %%
classifier_model.compile(optimizer = 'adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (2500, 21816, 1)
# (2500, 1)

# %%
classifier_history = classifier_model.fit(X_train,
                                          Y_train,
                                          epochs=50)
# Out:
# Epoch 1/50
# 79/79 [==============================] - 5s 59ms/step - loss: 2.0057 - accuracy: 0.2672
# Epoch 2/50
# 79/79 [==============================] - 4s 48ms/step - loss: 1.7932 - accuracy: 0.3296
# Epoch 3/50
# 79/79 [==============================] - 4s 49ms/step - loss: 1.3966 - accuracy: 0.4384
# Epoch 4/50
# 79/79 [==============================] - 4s 51ms/step - loss: 0.9254 - accuracy: 0.5768
# Epoch 5/50
# 79/79 [==============================] - 4s 52ms/step - loss: 0.7365 - accuracy: 0.6684
# Epoch 6/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.6549 - accuracy: 0.7012
# Epoch 7/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.4989 - accuracy: 0.7828
# Epoch 8/50
# 79/79 [==============================] - 4s 51ms/step - loss: 0.4511 - accuracy: 0.8136
# Epoch 9/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.3982 - accuracy: 0.8456
# Epoch 10/50
# 79/79 [==============================] - 4s 51ms/step - loss: 0.4225 - accuracy: 0.8388
# Epoch 11/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.2754 - accuracy: 0.9044
# Epoch 12/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.2026 - accuracy: 0.9360
# Epoch 13/50
# 79/79 [==============================] - 4s 52ms/step - loss: 0.2268 - accuracy: 0.9216
# Epoch 14/50
# 79/79 [==============================] - 4s 52ms/step - loss: 0.1323 - accuracy: 0.9572
# Epoch 15/50
# 79/79 [==============================] - 4s 53ms/step - loss: 0.1422 - accuracy: 0.9568
# Epoch 16/50
# 79/79 [==============================] - 5s 59ms/step - loss: 0.1101 - accuracy: 0.9664
# Epoch 17/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.1085 - accuracy: 0.9700
# Epoch 18/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.1311 - accuracy: 0.9632
# Epoch 19/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0904 - accuracy: 0.9756
# Epoch 20/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0680 - accuracy: 0.9796
# Epoch 21/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0593 - accuracy: 0.9836
# Epoch 22/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.1332 - accuracy: 0.9572
# Epoch 23/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.1382 - accuracy: 0.9576
# Epoch 24/50
# 79/79 [==============================] - 4s 52ms/step - loss: 0.0753 - accuracy: 0.9780
# Epoch 25/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0543 - accuracy: 0.9852
# Epoch 26/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0489 - accuracy: 0.9872
# Epoch 27/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0721 - accuracy: 0.9772
# Epoch 28/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.1135 - accuracy: 0.9636
# Epoch 29/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0569 - accuracy: 0.9840
# Epoch 30/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0630 - accuracy: 0.9840
# Epoch 31/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0486 - accuracy: 0.9864
# Epoch 32/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0590 - accuracy: 0.9856
# Epoch 33/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.1164 - accuracy: 0.9664
# Epoch 34/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0997 - accuracy: 0.9724
# Epoch 35/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0548 - accuracy: 0.9860
# Epoch 36/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0689 - accuracy: 0.9828
# Epoch 37/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0259 - accuracy: 0.9928
# Epoch 38/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0351 - accuracy: 0.9912
# Epoch 39/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0467 - accuracy: 0.9876
# Epoch 40/50
# 79/79 [==============================] - 4s 49ms/step - loss: 0.0294 - accuracy: 0.9932
# Epoch 41/50
# 79/79 [==============================] - 4s 53ms/step - loss: 0.0329 - accuracy: 0.9920
# Epoch 42/50
# 79/79 [==============================] - 4s 51ms/step - loss: 0.1050 - accuracy: 0.9720
# Epoch 43/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0805 - accuracy: 0.9788
# Epoch 44/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0656 - accuracy: 0.9808
# Epoch 45/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0250 - accuracy: 0.9928
# Epoch 46/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0130 - accuracy: 0.9964
# Epoch 47/50
# 79/79 [==============================] - 4s 49ms/step - loss: 0.0143 - accuracy: 0.9980
# Epoch 48/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0273 - accuracy: 0.9940
# Epoch 49/50
# 79/79 [==============================] - 4s 52ms/step - loss: 0.0379 - accuracy: 0.9920
# Epoch 50/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0555 - accuracy: 0.9844

# %% [markdown]
# ### Performance Stats

# %%
fig, ax = plt.subplots(1,2);
fig.set_size_inches(14,7);

ax[0].plot(classifier_history.history['accuracy'])

ax[0].set_xlabel("epoch", fontsize=20)
ax[0].set_ylabel("accuracy %", fontsize=20)
ax[0].legend()

ax[1].plot(classifier_history.history['loss'])

ax[1].set_xlabel("epoch", fontsize=20)
ax[1].set_ylabel("training loss", fontsize=20)
ax[1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
Y_pred = classifier_model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

matrix = confusion_matrix(y_test, y_pred, normalize='true', labels=[0,1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

labels = ['0', '1', '2', '3', '4', '5', '6']

grid = np.array(matrix)
im = ax.imshow(grid)

for k in range (0, len(grid)):
        for l in range (0, len(grid[0])):
            ax.text(l-0.3, k+0.1, str(grid[k][l])[:4], size=20, color='white')
            
ax.set_xticklabels([''] + labels);
ax.set_yticklabels([''] + labels);

ax.set_ylabel('True Pulse Number', fontsize=20);
ax.set_xlabel('Classified Pulse Number', fontsize=20);

#ax.set_title("with autoencoder", fontsize=20)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_test, alpha=0.5, label='True Pulse Number')
ax.hist(y_pred, alpha=0.5, label='Classified Pulse Number')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_train, alpha=0.5, label='y train')
ax.hist(y_test, alpha=0.5, label='y test')
ax.legend()

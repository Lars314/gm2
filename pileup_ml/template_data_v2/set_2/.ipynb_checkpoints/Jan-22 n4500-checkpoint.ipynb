# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as skl
import pickle
import spliland
import importlib
import random
import fclParse
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# Welcome to JupyROOT 6.18/04

# %%
directory = './template_data_v2/set_2/'

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Intro
#
# The purpose of this notebook is to make a second attempt at a neural network, following along with what was described in the paper "Deep Learning Based Pulse Shape Analysis for GERDA" by Philipp Holl in 2017. This algorithm consists of an autoencoder, decoder, and then classifier.
#
# I am also following this guide: https://keras.io/examples/timeseries/timeseries_anomaly_detection/ for the implementation of the layers described in the paper into python

# %% [markdown]
# ### Prep the data

# %%
n_points = 4500

with open(directory + 'x.data', 'rb') as xFile:
    biggestX = pickle.load(xFile)
    x_train = []
    x_test = []
    for x in biggestX[:n_points]:
        x_train.append(x)
    for x in biggestX[n_points:n_points+500]:
        x_test.append(x)
    xFile.close()

with open(directory + 'y.data', 'rb') as yFile:
    biggestY = pickle.load(yFile)
    y_train = biggestY[:n_points]
    y_test = biggestY[n_points:n_points+500]
    yFile.close()
    
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = np.reshape(x_train, (n_points, 21816, 1))
Y_train = np.reshape(y_train, (n_points, 1))

# %%
X_train.shape
# Out:
# (4500, 21816, 1)

# %% [markdown]
# ### Classifier

# %%
classifier_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(21816,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu')
])

# %%
classifier_model.compile(optimizer = 'adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (4500, 21816, 1)
# (4500, 1)

# %%
classifier_history = classifier_model.fit(X_train,
                                          Y_train,
                                          epochs=50)
# Out:
# Epoch 1/50
# 141/141 [==============================] - 7s 49ms/step - loss: 1.4865 - accuracy: 0.3393
# Epoch 2/50
# 141/141 [==============================] - 7s 49ms/step - loss: 1.1454 - accuracy: 0.4724
# Epoch 3/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.9392 - accuracy: 0.5449
# Epoch 4/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.7837 - accuracy: 0.6413
# Epoch 5/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.6564 - accuracy: 0.6996
# Epoch 6/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.5300 - accuracy: 0.7736
# Epoch 7/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.4594 - accuracy: 0.8127
# Epoch 8/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.3446 - accuracy: 0.8609
# Epoch 9/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.3198 - accuracy: 0.8760
# Epoch 10/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.2101 - accuracy: 0.9260
# Epoch 11/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.1523 - accuracy: 0.9469
# Epoch 12/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.1602 - accuracy: 0.9469 0s - loss: 0.1605 - accuracy
# Epoch 13/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.1469 - accuracy: 0.9496
# Epoch 14/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.1048 - accuracy: 0.9660
# Epoch 15/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.1474 - accuracy: 0.9596
# Epoch 16/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.1219 - accuracy: 0.9633
# Epoch 17/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0997 - accuracy: 0.9669
# Epoch 18/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0972 - accuracy: 0.9687
# Epoch 19/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0579 - accuracy: 0.9833
# Epoch 20/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0443 - accuracy: 0.9878
# Epoch 21/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0805 - accuracy: 0.9744
# Epoch 22/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0841 - accuracy: 0.9731
# Epoch 23/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0697 - accuracy: 0.9780
# Epoch 24/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0552 - accuracy: 0.9818
# Epoch 25/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0775 - accuracy: 0.9744
# Epoch 26/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0679 - accuracy: 0.9780
# Epoch 27/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0404 - accuracy: 0.9871
# Epoch 28/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0369 - accuracy: 0.9902
# Epoch 29/50
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0460 - accuracy: 0.9884
# Epoch 30/50
# 141/141 [==============================] - 8s 56ms/step - loss: 0.0358 - accuracy: 0.9916
# Epoch 31/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0590 - accuracy: 0.9800
# Epoch 32/50
# 141/141 [==============================] - 7s 51ms/step - loss: 0.0721 - accuracy: 0.9791
# Epoch 33/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0411 - accuracy: 0.9898
# Epoch 34/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0858 - accuracy: 0.9740
# Epoch 35/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.1081 - accuracy: 0.9809
# Epoch 36/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0445 - accuracy: 0.9876
# Epoch 37/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0325 - accuracy: 0.9922
# Epoch 38/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0414 - accuracy: 0.9871
# Epoch 39/50
# 141/141 [==============================] - 7s 51ms/step - loss: 0.0556 - accuracy: 0.9838
# Epoch 40/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0546 - accuracy: 0.9853
# Epoch 41/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0666 - accuracy: 0.9816
# Epoch 42/50
# 141/141 [==============================] - 8s 54ms/step - loss: 0.0609 - accuracy: 0.9829
# Epoch 43/50
# 141/141 [==============================] - 7s 52ms/step - loss: 0.0599 - accuracy: 0.9833
# Epoch 44/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0607 - accuracy: 0.9820
# Epoch 45/50
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0466 - accuracy: 0.9869
# Epoch 46/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0446 - accuracy: 0.9873
# Epoch 47/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0446 - accuracy: 0.9880
# Epoch 48/50
# 141/141 [==============================] - 7s 51ms/step - loss: 0.0289 - accuracy: 0.9918
# Epoch 49/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0510 - accuracy: 0.9873
# Epoch 50/50
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0373 - accuracy: 0.9891

# %% [markdown]
# ### Performance Stats

# %%
fig, ax = plt.subplots(1,2);
fig.set_size_inches(14,7);

ax[0].plot(classifier_history.history['accuracy'])

ax[0].set_xlabel("epoch", fontsize=20)
ax[0].set_ylabel("accuracy %", fontsize=20)
ax[0].legend()

ax[1].plot(classifier_history.history['loss'])

ax[1].set_xlabel("epoch", fontsize=20)
ax[1].set_ylabel("training loss", fontsize=20)
ax[1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
Y_pred = classifier_model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

matrix = confusion_matrix(y_test, y_pred, normalize='true', labels=[0,1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

labels = ['0', '1', '2', '3', '4', '5', '6']

grid = np.array(matrix)
im = ax.imshow(grid)

for k in range (0, len(grid)):
        for l in range (0, len(grid[0])):
            ax.text(l-0.3, k+0.1, str(grid[k][l])[:4], size=20, color='white')
            
ax.set_xticklabels([''] + labels);
ax.set_yticklabels([''] + labels);

ax.set_ylabel('True Pulse Number', fontsize=20);
ax.set_xlabel('Classified Pulse Number', fontsize=20);

#ax.set_title("with autoencoder", fontsize=20)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_test, alpha=0.5, label='True Pulse Number')
ax.hist(y_pred, alpha=0.5, label='Classified Pulse Number')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_train, alpha=0.5, label='y train')
ax.hist(y_test, alpha=0.5, label='y test')
ax.legend()

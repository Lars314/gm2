# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as skl
import pickle
import spliland
import importlib
import random
import fclParse
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# Welcome to JupyROOT 6.18/04

# %%
directory = './template_data_v2/set_2/'

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Intro
#
# The purpose of this notebook is to make a second attempt at a neural network, following along with what was described in the paper "Deep Learning Based Pulse Shape Analysis for GERDA" by Philipp Holl in 2017. This algorithm consists of an autoencoder, decoder, and then classifier.
#
# I am also following this guide: https://keras.io/examples/timeseries/timeseries_anomaly_detection/ for the implementation of the layers described in the paper into python

# %% [markdown]
# ### Prep the data

# %%
n_points = 1500

with open(directory + 'x.data', 'rb') as xFile:
    biggestX = pickle.load(xFile)
    x_train = []
    x_test = []
    for x in biggestX[:n_points]:
        x_train.append(x)
    for x in biggestX[n_points:n_points+500]:
        x_test.append(x)
    xFile.close()

with open(directory + 'y.data', 'rb') as yFile:
    biggestY = pickle.load(yFile)
    y_train = biggestY[:n_points]
    y_test = biggestY[n_points:n_points+500]
    yFile.close()
    
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = np.reshape(x_train, (n_points, 21816, 1))
Y_train = np.reshape(y_train, (n_points, 1))

# %%
X_train.shape
# Out:
# (1500, 21816, 1)

# %% [markdown]
# ### Classifier

# %%
classifier_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(21816,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu')
])

# %%
classifier_model.compile(optimizer = 'adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1500, 21816, 1)
# (1500, 1)

# %%
classifier_history = classifier_model.fit(X_train,
                                          Y_train,
                                          epochs=50)
# Out:
# Epoch 1/50
# 47/47 [==============================] - 2s 52ms/step - loss: 2.2015 - accuracy: 0.2460
# Epoch 2/50
# 47/47 [==============================] - 2s 51ms/step - loss: 1.8759 - accuracy: 0.2800
# Epoch 3/50
# 47/47 [==============================] - 3s 57ms/step - loss: 1.7436 - accuracy: 0.3427
# Epoch 4/50
# 47/47 [==============================] - 3s 59ms/step - loss: 1.4819 - accuracy: 0.3740
# Epoch 5/50
# 47/47 [==============================] - 2s 51ms/step - loss: 1.0253 - accuracy: 0.5787
# Epoch 6/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.7937 - accuracy: 0.6360
# Epoch 7/50
# 47/47 [==============================] - 3s 61ms/step - loss: 0.6750 - accuracy: 0.7207
# Epoch 8/50
# 47/47 [==============================] - 3s 61ms/step - loss: 0.5787 - accuracy: 0.7240
# Epoch 9/50
# 47/47 [==============================] - 3s 57ms/step - loss: 0.4834 - accuracy: 0.7967
# Epoch 10/50
# 47/47 [==============================] - 3s 55ms/step - loss: 0.3817 - accuracy: 0.8500
# Epoch 11/50
# 47/47 [==============================] - 3s 55ms/step - loss: 0.3679 - accuracy: 0.8633
# Epoch 12/50
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3813 - accuracy: 0.8407
# Epoch 13/50
# 47/47 [==============================] - 11s 239ms/step - loss: 0.3236 - accuracy: 0.8727
# Epoch 14/50
# 47/47 [==============================] - 2s 52ms/step - loss: 0.2367 - accuracy: 0.9153
# Epoch 15/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.1667 - accuracy: 0.9540
# Epoch 16/50
# 47/47 [==============================] - 3s 64ms/step - loss: 0.1788 - accuracy: 0.9367
# Epoch 17/50
# 47/47 [==============================] - 3s 68ms/step - loss: 0.2572 - accuracy: 0.9047
# Epoch 18/50
# 47/47 [==============================] - 3s 59ms/step - loss: 0.1013 - accuracy: 0.9680
# Epoch 19/50
# 47/47 [==============================] - 4s 85ms/step - loss: 0.0520 - accuracy: 0.9847
# Epoch 20/50
# 47/47 [==============================] - 3s 55ms/step - loss: 0.0770 - accuracy: 0.9767
# Epoch 21/50
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0564 - accuracy: 0.9853
# Epoch 22/50
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0418 - accuracy: 0.9867
# Epoch 23/50
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0593 - accuracy: 0.9840
# Epoch 24/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0565 - accuracy: 0.9813
# Epoch 25/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.1205 - accuracy: 0.9653
# Epoch 26/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0725 - accuracy: 0.9807
# Epoch 27/50
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0349 - accuracy: 0.9873
# Epoch 28/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0741 - accuracy: 0.9793
# Epoch 29/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0538 - accuracy: 0.9880
# Epoch 30/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0327 - accuracy: 0.9907
# Epoch 31/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0321 - accuracy: 0.9907
# Epoch 32/50
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0118 - accuracy: 0.9987
# Epoch 33/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0238 - accuracy: 0.9913
# Epoch 34/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.1525 - accuracy: 0.9500
# Epoch 35/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.1029 - accuracy: 0.9653
# Epoch 36/50
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0647 - accuracy: 0.9780
# Epoch 37/50
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0518 - accuracy: 0.9860
# Epoch 38/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0370 - accuracy: 0.9887
# Epoch 39/50
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0686 - accuracy: 0.9807
# Epoch 40/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0278 - accuracy: 0.9927
# Epoch 41/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0134 - accuracy: 0.9973
# Epoch 42/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0749 - accuracy: 0.9860
# Epoch 43/50
# 47/47 [==============================] - 3s 56ms/step - loss: 0.1315 - accuracy: 0.9567
# Epoch 44/50
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0671 - accuracy: 0.9813
# Epoch 45/50
# 47/47 [==============================] - 3s 57ms/step - loss: 0.0485 - accuracy: 0.9873
# Epoch 46/50
# 47/47 [==============================] - 3s 55ms/step - loss: 0.0212 - accuracy: 0.9947
# Epoch 47/50
# 47/47 [==============================] - 3s 55ms/step - loss: 0.0100 - accuracy: 0.9987
# Epoch 48/50
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0080 - accuracy: 0.9980
# Epoch 49/50
# 47/47 [==============================] - 3s 59ms/step - loss: 0.0115 - accuracy: 0.9980
# Epoch 50/50
# 47/47 [==============================] - 3s 61ms/step - loss: 0.0070 - accuracy: 0.9993

# %% [markdown]
# ### Performance Stats

# %%
fig, ax = plt.subplots(1,2);
fig.set_size_inches(14,7);

ax[0].plot(classifier_history.history['accuracy'])

ax[0].set_xlabel("epoch", fontsize=20)
ax[0].set_ylabel("accuracy %", fontsize=20)
ax[0].legend()

ax[1].plot(classifier_history.history['loss'])

ax[1].set_xlabel("epoch", fontsize=20)
ax[1].set_ylabel("training loss", fontsize=20)
ax[1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
Y_pred = classifier_model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

matrix = confusion_matrix(y_test, y_pred, normalize='true', labels=[0,1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

labels = ['0', '1', '2', '3', '4', '5', '6']

grid = np.array(matrix)
im = ax.imshow(grid)

for k in range (0, len(grid)):
        for l in range (0, len(grid[0])):
            ax.text(l-0.3, k+0.1, str(grid[k][l])[:4], size=20, color='white')
            
ax.set_xticklabels([''] + labels);
ax.set_yticklabels([''] + labels);

ax.set_ylabel('True Pulse Number', fontsize=20);
ax.set_xlabel('Classified Pulse Number', fontsize=20);

#ax.set_title("with autoencoder", fontsize=20)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_test, alpha=0.5, label='True Pulse Number')
ax.hist(y_pred, alpha=0.5, label='Classified Pulse Number')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_train, alpha=0.5, label='y train')
ax.hist(y_test, alpha=0.5, label='y test')
ax.legend()

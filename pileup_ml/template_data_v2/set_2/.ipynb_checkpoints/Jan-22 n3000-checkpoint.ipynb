# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as skl
import pickle
import spliland
import importlib
import random
import fclParse
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# Welcome to JupyROOT 6.18/04

# %%
directory = './template_data_v2/set_2/'

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Intro
#
# The purpose of this notebook is to make a second attempt at a neural network, following along with what was described in the paper "Deep Learning Based Pulse Shape Analysis for GERDA" by Philipp Holl in 2017. This algorithm consists of an autoencoder, decoder, and then classifier.
#
# I am also following this guide: https://keras.io/examples/timeseries/timeseries_anomaly_detection/ for the implementation of the layers described in the paper into python

# %% [markdown]
# ### Prep the data

# %%
n_points = 3000

with open(directory + 'x.data', 'rb') as xFile:
    biggestX = pickle.load(xFile)
    x_train = []
    x_test = []
    for x in biggestX[:n_points]:
        x_train.append(x)
    for x in biggestX[n_points:n_points+500]:
        x_test.append(x)
    xFile.close()

with open(directory + 'y.data', 'rb') as yFile:
    biggestY = pickle.load(yFile)
    y_train = biggestY[:n_points]
    y_test = biggestY[n_points:n_points+500]
    yFile.close()
    
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = np.reshape(x_train, (n_points, 21816, 1))
Y_train = np.reshape(y_train, (n_points, 1))

# %%
X_train.shape
# Out:
# (3000, 21816, 1)

# %% [markdown]
# ### Classifier

# %%
classifier_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(21816,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu')
])

# %%
classifier_model.compile(optimizer = 'adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (3000, 21816, 1)
# (3000, 1)

# %%
classifier_history = classifier_model.fit(X_train,
                                          Y_train,
                                          epochs=50)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 5s 49ms/step - loss: 1.6116 - accuracy: 0.2893
# Epoch 2/50
# 94/94 [==============================] - 5s 50ms/step - loss: 1.2709 - accuracy: 0.4337
# Epoch 3/50
# 94/94 [==============================] - 5s 52ms/step - loss: 1.0867 - accuracy: 0.5167
# Epoch 4/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.8797 - accuracy: 0.5953
# Epoch 5/50
# 94/94 [==============================] - 5s 48ms/step - loss: 0.7653 - accuracy: 0.6570
# Epoch 6/50
# 94/94 [==============================] - 4s 47ms/step - loss: 0.6217 - accuracy: 0.7223
# Epoch 7/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.5031 - accuracy: 0.7810
# Epoch 8/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.4081 - accuracy: 0.8440
# Epoch 9/50
# 94/94 [==============================] - 5s 48ms/step - loss: 0.2879 - accuracy: 0.8900
# Epoch 10/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.2541 - accuracy: 0.9063
# Epoch 11/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.2143 - accuracy: 0.9300
# Epoch 12/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.1491 - accuracy: 0.9527
# Epoch 13/50
# 94/94 [==============================] - 5s 54ms/step - loss: 0.1658 - accuracy: 0.9447
# Epoch 14/50
# 94/94 [==============================] - 5s 53ms/step - loss: 0.1630 - accuracy: 0.9480
# Epoch 15/50
# 94/94 [==============================] - 5s 53ms/step - loss: 0.1175 - accuracy: 0.9673
# Epoch 16/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0917 - accuracy: 0.9747
# Epoch 17/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.1120 - accuracy: 0.9653
# Epoch 18/50
# 94/94 [==============================] - 5s 51ms/step - loss: 0.1499 - accuracy: 0.9547
# Epoch 19/50
# 94/94 [==============================] - 5s 48ms/step - loss: 0.1117 - accuracy: 0.9663
# Epoch 20/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.1211 - accuracy: 0.9647
# Epoch 21/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0946 - accuracy: 0.9690
# Epoch 22/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0682 - accuracy: 0.9853
# Epoch 23/50
# 94/94 [==============================] - 5s 52ms/step - loss: 0.0430 - accuracy: 0.9883
# Epoch 24/50
# 94/94 [==============================] - 5s 54ms/step - loss: 0.0483 - accuracy: 0.9850
# Epoch 25/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0904 - accuracy: 0.9757
# Epoch 26/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0763 - accuracy: 0.9787 0s - loss: 0.0
# Epoch 27/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.0499 - accuracy: 0.9897
# Epoch 28/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0502 - accuracy: 0.9880
# Epoch 29/50
# 94/94 [==============================] - 5s 52ms/step - loss: 0.0508 - accuracy: 0.9860
# Epoch 30/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0839 - accuracy: 0.9770
# Epoch 31/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.0836 - accuracy: 0.9753
# Epoch 32/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.1193 - accuracy: 0.9613
# Epoch 33/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0825 - accuracy: 0.9760
# Epoch 34/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0622 - accuracy: 0.9827
# Epoch 35/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0339 - accuracy: 0.9930
# Epoch 36/50
# 94/94 [==============================] - 5s 51ms/step - loss: 0.0311 - accuracy: 0.9913
# Epoch 37/50
# 94/94 [==============================] - 5s 52ms/step - loss: 0.0363 - accuracy: 0.9917
# Epoch 38/50
# 94/94 [==============================] - 5s 56ms/step - loss: 0.0578 - accuracy: 0.9830
# Epoch 39/50
# 94/94 [==============================] - 6s 65ms/step - loss: 0.0604 - accuracy: 0.9843
# Epoch 40/50
# 94/94 [==============================] - 5s 52ms/step - loss: 0.0865 - accuracy: 0.9770
# Epoch 41/50
# 94/94 [==============================] - 5s 48ms/step - loss: 0.0700 - accuracy: 0.9807
# Epoch 42/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0535 - accuracy: 0.9853
# Epoch 43/50
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0518 - accuracy: 0.9880
# Epoch 44/50
# 94/94 [==============================] - 5s 52ms/step - loss: 0.0357 - accuracy: 0.9913
# Epoch 45/50
# 94/94 [==============================] - 5s 51ms/step - loss: 0.0358 - accuracy: 0.9920
# Epoch 46/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.0348 - accuracy: 0.9903
# Epoch 47/50
# 94/94 [==============================] - 5s 55ms/step - loss: 0.1700 - accuracy: 0.9553
# Epoch 48/50
# 94/94 [==============================] - 6s 59ms/step - loss: 0.1015 - accuracy: 0.9757
# Epoch 49/50
# 94/94 [==============================] - 5s 51ms/step - loss: 0.0752 - accuracy: 0.9817
# Epoch 50/50
# 94/94 [==============================] - 5s 51ms/step - loss: 0.0423 - accuracy: 0.9910

# %% [markdown]
# ### Performance Stats

# %%
fig, ax = plt.subplots(1,2);
fig.set_size_inches(14,7);

ax[0].plot(classifier_history.history['accuracy'])

ax[0].set_xlabel("epoch", fontsize=20)
ax[0].set_ylabel("accuracy %", fontsize=20)
ax[0].legend()

ax[1].plot(classifier_history.history['loss'])

ax[1].set_xlabel("epoch", fontsize=20)
ax[1].set_ylabel("training loss", fontsize=20)
ax[1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
Y_pred = classifier_model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

matrix = confusion_matrix(y_test, y_pred, normalize='true', labels=[0,1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

labels = ['0', '1', '2', '3', '4', '5', '6']

grid = np.array(matrix)
im = ax.imshow(grid)

for k in range (0, len(grid)):
        for l in range (0, len(grid[0])):
            ax.text(l-0.3, k+0.1, str(grid[k][l])[:4], size=20, color='white')
            
ax.set_xticklabels([''] + labels);
ax.set_yticklabels([''] + labels);

ax.set_ylabel('True Pulse Number', fontsize=20);
ax.set_xlabel('Classified Pulse Number', fontsize=20);

#ax.set_title("with autoencoder", fontsize=20)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_test, alpha=0.5, label='True Pulse Number')
ax.hist(y_pred, alpha=0.5, label='Classified Pulse Number')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_train, alpha=0.5, label='y train')
ax.hist(y_test, alpha=0.5, label='y test')
ax.legend()

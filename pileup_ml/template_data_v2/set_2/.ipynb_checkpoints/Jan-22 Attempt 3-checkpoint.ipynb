# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as skl
import pickle
import spliland
import importlib
import random
import fclParse
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# Welcome to JupyROOT 6.18/04

# %%
directory = './template_data_v2/set_2/'

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Intro
#
# The purpose of this notebook is to make a second attempt at a neural network, following along with what was described in the paper "Deep Learning Based Pulse Shape Analysis for GERDA" by Philipp Holl in 2017. This algorithm consists of an autoencoder, decoder, and then classifier.
#
# I am also following this guide: https://keras.io/examples/timeseries/timeseries_anomaly_detection/ for the implementation of the layers described in the paper into python

# %% [markdown]
# ### Prep the data

# %%
n_points = 4500

with open(directory + 'x.data', 'rb') as xFile:
    biggestX = pickle.load(xFile)
    x_train = []
    x_test = []
    for x in biggestX[:n_points]:
        x_train.append(x)
    for x in biggestX[n_points:n_points+500]:
        x_test.append(x)
    xFile.close()

with open(directory + 'y.data', 'rb') as yFile:
    biggestY = pickle.load(yFile)
    y_train = biggestY[:n_points]
    y_test = biggestY[n_points:n_points+500]
    yFile.close()
    
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = np.reshape(x_train, (n_points, 21816, 1))
Y_train = np.reshape(y_train, (n_points, 1))

# %%
X_train.shape
# Out:
# (4500, 21816, 1)

# %% [markdown]
# ### Classifier

# %%
classifier_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(21816,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu')
])

# %%
classifier_model.compile(optimizer = 'adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (4500, 21816, 1)
# (4500, 1)

# %%
classifier_history = classifier_model.fit(X_train,
                                          Y_train,
                                          epochs=20)
# Out:
# Epoch 1/20
# 141/141 [==============================] - 6s 41ms/step - loss: 2.3456 - accuracy: 0.2849
# Epoch 2/20
# 141/141 [==============================] - 6s 41ms/step - loss: 1.9835 - accuracy: 0.3536
# Epoch 3/20
# 141/141 [==============================] - 6s 40ms/step - loss: 1.7494 - accuracy: 0.4156
# Epoch 4/20
# 141/141 [==============================] - 6s 41ms/step - loss: 1.6278 - accuracy: 0.4636
# Epoch 5/20
# 141/141 [==============================] - 6s 40ms/step - loss: 1.4858 - accuracy: 0.5053
# Epoch 6/20
# 141/141 [==============================] - 6s 45ms/step - loss: 1.3338 - accuracy: 0.5587
# Epoch 7/20
# 141/141 [==============================] - 6s 39ms/step - loss: 1.2487 - accuracy: 0.5891
# Epoch 8/20
# 141/141 [==============================] - 6s 40ms/step - loss: 1.1569 - accuracy: 0.6276
# Epoch 9/20
# 141/141 [==============================] - 6s 40ms/step - loss: 1.1091 - accuracy: 0.6531
# Epoch 10/20
# 141/141 [==============================] - 6s 40ms/step - loss: 1.0942 - accuracy: 0.6693
# Epoch 11/20
# 141/141 [==============================] - 6s 41ms/step - loss: 1.0299 - accuracy: 0.6782
# Epoch 12/20
# 141/141 [==============================] - 6s 40ms/step - loss: 0.9615 - accuracy: 0.6951
# Epoch 13/20
# 141/141 [==============================] - 6s 44ms/step - loss: 0.9110 - accuracy: 0.7098
# Epoch 14/20
# 141/141 [==============================] - 6s 40ms/step - loss: 0.9211 - accuracy: 0.7067
# Epoch 15/20
# 141/141 [==============================] - 6s 40ms/step - loss: 0.8886 - accuracy: 0.7171
# Epoch 16/20
# 141/141 [==============================] - 6s 40ms/step - loss: 0.8625 - accuracy: 0.7262
# Epoch 17/20
# 141/141 [==============================] - 6s 40ms/step - loss: 0.8595 - accuracy: 0.7296
# Epoch 18/20
# 141/141 [==============================] - 6s 40ms/step - loss: 0.8862 - accuracy: 0.7242
# Epoch 19/20
# 141/141 [==============================] - 6s 40ms/step - loss: 0.8602 - accuracy: 0.7276
# Epoch 20/20
# 141/141 [==============================] - 6s 41ms/step - loss: 0.8638 - accuracy: 0.7280

# %% [markdown]
# ### Performance Stats

# %%
fig, ax = plt.subplots(1,2);
fig.set_size_inches(14,7);

ax[0].plot(classifier_history.history['accuracy'])

ax[0].set_xlabel("epoch", fontsize=20)
ax[0].set_ylabel("accuracy %", fontsize=20)
ax[0].legend()

ax[1].plot(classifier_history.history['loss'])

ax[1].set_xlabel("epoch", fontsize=20)
ax[1].set_ylabel("training loss", fontsize=20)
ax[1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
Y_pred = classifier_model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

matrix = confusion_matrix(y_test, y_pred, normalize='true', labels=[0,1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

labels = ['0', '1', '2', '3', '4', '5', '6']

grid = np.array(matrix)
im = ax.imshow(grid)

for k in range (0, len(grid)):
        for l in range (0, len(grid[0])):
            ax.text(l-0.3, k+0.1, str(grid[k][l])[:4], size=20, color='white')
            
ax.set_xticklabels([''] + labels);
ax.set_yticklabels([''] + labels);

ax.set_ylabel('True Pulse Number', fontsize=20);
ax.set_xlabel('Classified Pulse Number', fontsize=20);

#ax.set_title("with autoencoder", fontsize=20)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_test, alpha=0.5, label='True Pulse Number')
ax.hist(y_pred, alpha=0.5, label='Classified Pulse Number')
# Out:
# (array([ 40.,   0.,   0., 105.,   0.,   0., 133.,   0.,   0., 222.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

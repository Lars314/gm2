# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as skl
import pickle
import spliland
import importlib
import random
import fclParse
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# Welcome to JupyROOT 6.18/04

# %%
directory = './template_data_v2/set_2/'

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Intro
#
# The purpose of this notebook is to make a second attempt at a neural network, following along with what was described in the paper "Deep Learning Based Pulse Shape Analysis for GERDA" by Philipp Holl in 2017. This algorithm consists of an autoencoder, decoder, and then classifier.
#
# I am also following this guide: https://keras.io/examples/timeseries/timeseries_anomaly_detection/ for the implementation of the layers described in the paper into python

# %% [markdown]
# ### Prep the data

# %%
n_points = 3500

with open(directory + 'x.data', 'rb') as xFile:
    biggestX = pickle.load(xFile)
    x_train = []
    x_test = []
    for x in biggestX[:n_points]:
        x_train.append(x)
    for x in biggestX[n_points:n_points+500]:
        x_test.append(x)
    xFile.close()

with open(directory + 'y.data', 'rb') as yFile:
    biggestY = pickle.load(yFile)
    y_train = biggestY[:n_points]
    y_test = biggestY[n_points:n_points+500]
    yFile.close()
    
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = np.reshape(x_train, (n_points, 21816, 1))
Y_train = np.reshape(y_train, (n_points, 1))

# %%
X_train.shape
# Out:
# (3500, 21816, 1)

# %% [markdown]
# ### Classifier

# %%
classifier_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(21816,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(20, activation='relu')
])

# %%
classifier_model.compile(optimizer = 'adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (3500, 21816, 1)
# (3500, 1)

# %%
classifier_history = classifier_model.fit(X_train,
                                          Y_train,
                                          epochs=50)
# Out:
# Epoch 1/50
# 110/110 [==============================] - 6s 50ms/step - loss: 2.7353 - accuracy: 0.2317
# Epoch 2/50
# 110/110 [==============================] - 5s 48ms/step - loss: 2.0856 - accuracy: 0.4463
# Epoch 3/50
# 110/110 [==============================] - 5s 48ms/step - loss: 1.6765 - accuracy: 0.5451
# Epoch 4/50
# 110/110 [==============================] - 6s 50ms/step - loss: 1.5078 - accuracy: 0.5980
# Epoch 5/50
# 110/110 [==============================] - 5s 48ms/step - loss: 1.3679 - accuracy: 0.6389
# Epoch 6/50
# 110/110 [==============================] - 5s 48ms/step - loss: 1.2340 - accuracy: 0.6709
# Epoch 7/50
# 110/110 [==============================] - 5s 49ms/step - loss: 1.1608 - accuracy: 0.6820
# Epoch 8/50
# 110/110 [==============================] - 5s 49ms/step - loss: 1.0690 - accuracy: 0.6969
# Epoch 9/50
# 110/110 [==============================] - 5s 49ms/step - loss: 1.0826 - accuracy: 0.6991
# Epoch 10/50
# 110/110 [==============================] - 5s 49ms/step - loss: 1.0239 - accuracy: 0.7020
# Epoch 11/50
# 110/110 [==============================] - 5s 49ms/step - loss: 0.9787 - accuracy: 0.7117
# Epoch 12/50
# 110/110 [==============================] - 5s 48ms/step - loss: 0.9197 - accuracy: 0.7166
# Epoch 13/50
# 110/110 [==============================] - 5s 49ms/step - loss: 0.8978 - accuracy: 0.7186
# Epoch 14/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.8758 - accuracy: 0.7274
# Epoch 15/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.9262 - accuracy: 0.7160
# Epoch 16/50
# 110/110 [==============================] - 6s 51ms/step - loss: 0.9090 - accuracy: 0.7177
# Epoch 17/50
# 110/110 [==============================] - 5s 50ms/step - loss: 0.8782 - accuracy: 0.7223
# Epoch 18/50
# 110/110 [==============================] - 5s 49ms/step - loss: 0.9073 - accuracy: 0.7200
# Epoch 19/50
# 110/110 [==============================] - 6s 51ms/step - loss: 0.9014 - accuracy: 0.7220
# Epoch 20/50
# 110/110 [==============================] - 5s 49ms/step - loss: 0.8747 - accuracy: 0.7237
# Epoch 21/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.8502 - accuracy: 0.7283
# Epoch 22/50
# 110/110 [==============================] - 6s 54ms/step - loss: 0.8781 - accuracy: 0.7237
# Epoch 23/50
# 110/110 [==============================] - 6s 57ms/step - loss: 0.8630 - accuracy: 0.7283
# Epoch 24/50
# 110/110 [==============================] - 11s 97ms/step - loss: 0.8391 - accuracy: 0.7311
# Epoch 25/50
# 110/110 [==============================] - 7s 63ms/step - loss: 0.8345 - accuracy: 0.7297
# Epoch 26/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.9990 - accuracy: 0.7054
# Epoch 27/50
# 110/110 [==============================] - 6s 51ms/step - loss: 0.9040 - accuracy: 0.7203
# Epoch 28/50
# 110/110 [==============================] - 6s 50ms/step - loss: 0.8634 - accuracy: 0.7229
# Epoch 29/50
# 110/110 [==============================] - 6s 50ms/step - loss: 0.8545 - accuracy: 0.7251
# Epoch 30/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.8284 - accuracy: 0.7306
# Epoch 31/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.8562 - accuracy: 0.7254
# Epoch 32/50
# 110/110 [==============================] - 6s 51ms/step - loss: 0.8521 - accuracy: 0.7257
# Epoch 33/50
# 110/110 [==============================] - 5s 50ms/step - loss: 0.8366 - accuracy: 0.7266
# Epoch 34/50
# 110/110 [==============================] - 6s 50ms/step - loss: 0.8362 - accuracy: 0.7297 0s - loss: 0.828
# Epoch 35/50
# 110/110 [==============================] - 5s 50ms/step - loss: 0.8586 - accuracy: 0.7266
# Epoch 36/50
# 110/110 [==============================] - 6s 53ms/step - loss: 0.8491 - accuracy: 0.7289
# Epoch 37/50
# 110/110 [==============================] - 7s 63ms/step - loss: 0.8592 - accuracy: 0.7251
# Epoch 38/50
# 110/110 [==============================] - 7s 64ms/step - loss: 0.8579 - accuracy: 0.7246
# Epoch 39/50
# 110/110 [==============================] - 6s 53ms/step - loss: 0.8465 - accuracy: 0.7271
# Epoch 40/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.8452 - accuracy: 0.7289
# Epoch 41/50
# 110/110 [==============================] - 6s 51ms/step - loss: 0.8350 - accuracy: 0.7297
# Epoch 42/50
# 110/110 [==============================] - 5s 50ms/step - loss: 0.8434 - accuracy: 0.7314
# Epoch 43/50
# 110/110 [==============================] - 6s 51ms/step - loss: 0.8300 - accuracy: 0.7311
# Epoch 44/50
# 110/110 [==============================] - 7s 59ms/step - loss: 0.8493 - accuracy: 0.7251
# Epoch 45/50
# 110/110 [==============================] - 6s 55ms/step - loss: 0.8315 - accuracy: 0.7303
# Epoch 46/50
# 110/110 [==============================] - 6s 54ms/step - loss: 0.8182 - accuracy: 0.7314
# Epoch 47/50
# 110/110 [==============================] - 6s 52ms/step - loss: 0.8238 - accuracy: 0.7303
# Epoch 48/50
# 110/110 [==============================] - 6s 50ms/step - loss: 0.8346 - accuracy: 0.7277
# Epoch 49/50
# 110/110 [==============================] - 5s 50ms/step - loss: 0.8696 - accuracy: 0.7263
# Epoch 50/50
# 110/110 [==============================] - 6s 51ms/step - loss: 0.8751 - accuracy: 0.7231

# %% [markdown]
# ### Performance Stats

# %%
fig, ax = plt.subplots(1,2);
fig.set_size_inches(14,7);

ax[0].plot(classifier_history.history['accuracy'])

ax[0].set_xlabel("epoch", fontsize=20)
ax[0].set_ylabel("accuracy %", fontsize=20)
ax[0].legend()

ax[1].plot(classifier_history.history['loss'])

ax[1].set_xlabel("epoch", fontsize=20)
ax[1].set_ylabel("training loss", fontsize=20)
ax[1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
Y_pred = classifier_model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

matrix = confusion_matrix(y_test, y_pred, normalize='true', labels=[0,1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

labels = ['0', '1', '2', '3', '4', '5', '6']

grid = np.array(matrix)
im = ax.imshow(grid)

for k in range (0, len(grid)):
        for l in range (0, len(grid[0])):
            ax.text(l-0.3, k+0.1, str(grid[k][l])[:4], size=20, color='white')
            
ax.set_xticklabels([''] + labels);
ax.set_yticklabels([''] + labels);

ax.set_ylabel('True Pulse Number', fontsize=20);
ax.set_xlabel('Classified Pulse Number', fontsize=20);

#ax.set_title("with autoencoder", fontsize=20)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_test, alpha=0.5, label='True Pulse Number')
ax.hist(y_pred, alpha=0.5, label='Classified Pulse Number')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(7, 7)

ax.hist(y_train, alpha=0.5, label='y train')
ax.hist(y_test, alpha=0.5, label='y test')
ax.legend()

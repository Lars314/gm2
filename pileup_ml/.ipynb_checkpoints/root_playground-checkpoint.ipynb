# %%
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Welcome to JupyROOT 6.18/04

# %%
f = r.TFile("./sample_data_4.root")

# %%
f.cd("islandFits1/fits")
f.ls()
# Out:
# TFile**		./sample_data_4.root
#  TFile*		./sample_data_4.root
#   TDirectoryFile*		islandFits1	islandFits1 (IslandFitDisplayTree) folder
#    TDirectoryFile*		fits	fits
#     KEY: TTree	fitTree;1	fitTree
#    KEY: TDirectoryFile	splines;1	splines
#    KEY: TDirectoryFile	fits;1	fits
#   KEY: TDirectoryFile	islands;1	islands (CaloIslandAnalyzer) folder
#   KEY: TDirectoryFile	islandFits1;1	islandFits1 (IslandFitDisplayTree) folder

# %%
tree = f.Get("islandFits1/fits/fitTree")

# %%
tree.Print()
# Out:
# ******************************************************************************
# *Tree    :fitTree   : fitTree                                                *
# *Entries :      422 : Total =          124670 bytes  File  Size =      45482 *
# *        :          : Tree compression factor =   2.65                       *
# ******************************************************************************
# *Br    0 :caloNum   : caloNum/I                                              *
# *Entries :      422 : Total  Size=       2258 bytes  File Size  =        117 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  15.09     *
# *............................................................................*
# *Br    1 :xtalNum   : xtalNum/I                                              *
# *Entries :      422 : Total  Size=       2258 bytes  File Size  =        591 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.99     *
# *............................................................................*
# *Br    2 :fillNum   : fillNum/I                                              *
# *Entries :      422 : Total  Size=       2258 bytes  File Size  =        284 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   6.21     *
# *............................................................................*
# *Br    3 :subRunNum : subRunNum/I                                            *
# *Entries :      422 : Total  Size=       2268 bytes  File Size  =        119 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  14.85     *
# *............................................................................*
# *Br    4 :runNum    : runNum/I                                               *
# *Entries :      422 : Total  Size=       2253 bytes  File Size  =        116 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  15.21     *
# *............................................................................*
# *Br    5 :islandNums : vector<int>                                           *
# *Entries :      422 : Total  Size=       8193 bytes  File Size  =       1263 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   6.08     *
# *............................................................................*
# *Br    6 :chainedIslandNums : vector<int>                                    *
# *Entries :      422 : Total  Size=       8228 bytes  File Size  =       1272 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   6.05     *
# *............................................................................*
# *Br    7 :firstSampleNums : vector<int>                                      *
# *Entries :      422 : Total  Size=       8218 bytes  File Size  =       1503 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.12     *
# *............................................................................*
# *Br    8 :islandLengths : vector<int>                                        *
# *Entries :      422 : Total  Size=       8208 bytes  File Size  =       1198 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   6.42     *
# *............................................................................*
# *Br    9 :chi2      : chi2/D                                                 *
# *Entries :      422 : Total  Size=       3939 bytes  File Size  =       3302 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.04     *
# *............................................................................*
# *Br   10 :pedestal  : pedestal/D                                             *
# *Entries :      422 : Total  Size=       3959 bytes  File Size  =       3159 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br   11 :energies  : vector<double>                                         *
# *Entries :      422 : Total  Size=       9879 bytes  File Size  =       4561 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.06     *
# *............................................................................*
# *Br   12 :times     : vector<double>                                         *
# *Entries :      422 : Total  Size=       9864 bytes  File Size  =       4110 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.28     *
# *............................................................................*
# *Br   13 :statuses  : vector<int>                                            *
# *Entries :      422 : Total  Size=       8187 bytes  File Size  =        877 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   8.76     *
# *............................................................................*
# *Br   14 :trace     : vector<short>                                          *
# *Entries :      422 : Total  Size=      36489 bytes  File Size  =      20476 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.76     *
# *............................................................................*
# *Br   15 :laserHits : vector<short>                                          *
# *Entries :      422 : Total  Size=       7346 bytes  File Size  =        801 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   8.54     *
# *............................................................................*

# %%
c = r.TCanvas()
tree.Draw("times", "", "colz")
c.SetLogy()
c.Draw()

# %%
c = r.TCanvas()
tree.Draw("times:laserHits", "", "colz")
c.Draw()

# %%
c = r.TCanvas()
tree.Draw("laserHits:@laserHits.size()", "", "colz")
c.Draw()

# %%
tree.BuildIndex("laserHits")
# Out:
# 276156

# %%
bruh = []
for i in range(0, 276156):
    bruh.append(tree.GetEntryWithIndex(i))

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,7)

ax.hist(bruh)
# Out:
# (array([2.76154e+05, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([ -1. ,  23.5,  48. ,  72.5,  97. , 121.5, 146. , 170.5, 195. ,
#         219.5, 244. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Haha yes uproot exists

# %%
import uproot

# %%
file = uproot.open("sample_data_4.root")
tree = file["islandFits1/fits/fitTree"]

# %%
tree.keys()
# Out:
# [b'caloNum',
#  b'xtalNum',
#  b'fillNum',
#  b'subRunNum',
#  b'runNum',
#  b'islandNums',
#  b'chainedIslandNums',
#  b'firstSampleNums',
#  b'islandLengths',
#  b'chi2',
#  b'pedestal',
#  b'energies',
#  b'times',
#  b'statuses',
#  b'trace',
#  b'laserHits']

# %%
traces = tree['trace'].array()
energies = tree['energies'].array()
times = tree['times'].array()
pedestals = tree['pedestal'].array()

bruh_indices = []
print("Looking at energy...")
i = 0
for energy in energies:
    if(len(energy) != 1):
        print("Found bad index {0} with {1} pulses".format(i, len(energy)))
        bruh_indices.append(i)
    i += 1
# Out:
# Looking at energy...
# Found bad index 6 with 2 pulses

# %%
df = pd.DataFrame(columns=('time','energy','pedestal','trace'))
i = 0
for j in range(0, len(energies)):
    if(j in bruh_indices):
        continue
    
    this_energy = float(energies[j])
    this_trace = np.array(traces[j])
    this_time = float(times[j])
    this_pedestal = float(pedestals[j])
    df.loc[i] = [this_time, this_energy,this_pedestal, this_trace]
    i += 1

# %%
df.head()
# Out:
#             time       energy     pedestal  \
# 0  327055.691186   190.713001 -1764.531319
# 1  327055.387862    87.732285 -1797.883538
# 2  327056.264074  2898.905221 -1798.199782
# 3  327056.588284   348.623868 -1765.523640
# 4  406465.561623    81.521892 -1794.700957
#
#                                                trace
# 0  [-1764, -1767, -1761, -1770, -1765, -1763, -17...
# 1  [-1798, -1795, -1800, -1799, -1802, -1796, -18...
# 2  [-1796, -1795, -1799, -1798, -1802, -1797, -17...
# 3  [-1765, -1764, -1778, -1762, -1767, -1758, -17...
# 4  [-1783, -1797, -1793, -1800, -1793, -1799, -17...

# %%
df.to_csv("sample_data_4.csv")

# %%
fig, ax = plt.subplots(1,1)

index = np.random.randint(low=0, high=420)

stuff = df.loc[index]
thing = \
"time: {0:.0f} \n\
energy: {1:.0f} \n\
pedestal: {2:.0f} \
".format(stuff['time'], stuff['energy'], stuff['pedestal'])

ax.plot(stuff['trace'], label=thing)
ax.legend(fontsize='large')

# %%
smh = np.ndarray(shape=(2,3))

# %%
smh
# Out:
# array([[ 0., 30.,  0.],
#        [15.,  0.,  0.]])

# %%
energy_distribution = df['energy']

# %%
df['energy'][1]
# Out:
# 87.7322852709117

# %%
import calospliland as csi
import importlib
import ROOT as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Welcome to JupyROOT 6.18/04

# %%
# Reload stuff in case you make changes!
importlib.reload(csi);

# %%
calo = csi.Calorimeter(caloNum=1)
df = pd.read_csv("sample_data_4.csv")
calo.draw(legend=False)

# %%
p1 = csi.Particle(e_df=df['energy'])
print("p1 x: {0:.2f} \np1 y: {1:.2f}".format(p1.x, p1.y) + 
      "\np1 energy: {0:.2f} MeV".format(p1.energy) +
      "\np1 time: {0:.2f} ns".format(p1.time))
calo.impact(p1)
calo.get_hit_crystals_()
calo.draw(legend=True, do_moliere_radius=True, show_hit_xtals=True)
# Out:
# p1 x: 2.91
# p1 y: 2.02
# p1 energy: 101.17 MeV
# p1 time: 19.40 ns

# %%
calo.get_hit_crystals()

# %%
calo.impacts
# Out:
# [{'x': 5.749218283978353,
#   'y': 1.119035563920745,
#   'time': 19.73782150620123,
#   'energy': 133.96134375807742,
#   'ring_x': array([7.16654112, 7.05865384, 6.75141687, 6.29160425, 5.74921828,
#          5.20683232, 4.7470197 , 4.43978273, 4.33189545, 4.43978273,
#          4.7470197 , 5.20683232, 5.74921828, 6.29160425, 6.75141687,
#          7.05865384, 7.16654112]),
#   'ring_y': array([ 1.11903556,  1.66142153,  2.12123415,  2.42847112,  2.5363584 ,
#           2.42847112,  2.12123415,  1.66142153,  1.11903556,  0.5766496 ,
#           0.11683698, -0.19039999, -0.29828727, -0.19039999,  0.11683698,
#           0.5766496 ,  1.11903556]),
#   'small_ring_x': array([6.4578797 , 6.40393606, 6.25031758, 6.02041127, 5.74921828,
#          5.4780253 , 5.24811899, 5.09450051, 5.04055687, 5.09450051,
#          5.24811899, 5.4780253 , 5.74921828, 6.02041127, 6.25031758,
#          6.40393606, 6.4578797 ]),
#   'small_ring_y': array([1.11903556, 1.39022855, 1.62013486, 1.77375334, 1.82769698,
#          1.77375334, 1.62013486, 1.39022855, 1.11903556, 0.84784258,
#          0.61793627, 0.46431778, 0.41037415, 0.46431778, 0.61793627,
#          0.84784258, 1.11903556]),
#   'hit_crystals': [(7, 1),
#    (6, 2),
#    (5, 2),
#    (4, 2),
#    (4, 1),
#    (4, 0),
#    (5, 0),
#    (6, 0),
#    (7, 0),
#    (6, 1),
#    (5, 1)]}]

# %%
p2 = csi.Particle(e_df=df['energy'])
print("p2 x: {0:.2f} \np2 y: {1:.2f}".format(p2.x, p2.y) + 
      "\np2 energy: {0:.2f} MeV".format(p2.energy) +
      "\np2 time: {0:.2f} ns".format(p2.time))
calo.impact(p2)
calo.draw(legend=True, do_moliere_radius=True)
# Out:
# p2 x: 0.97
# p2 y: 1.70
# p2 energy: 539.95 MeV
# p2 time: 3.60 ns

# %%
calo.impacts
# Out:
# [{'x': 2.239468555527834,
#   'y': 5.201381471772806,
#   'time': 12.295217307577424,
#   'energy': 85.72527463608314,
#   'ring_x': array([3.65679139, 3.65387935, 3.64515519, 3.63065476, 3.61043765,
#          3.58458694, 3.55320884, 3.51643231, 3.47440845, 3.42730996,
#          3.37533038, 3.3186833 , 3.25760149, 3.19233596, 3.12315489,
#          3.05034256, 2.97419818, 2.89503464, 2.81317723, 2.72896233,
#          2.642736  , 2.55485256, 2.46567313, 2.37556418, 2.28489599,
#          2.19404112, 2.10337293, 2.01326398, 1.92408455, 1.83620111,
#          1.74997478, 1.66575988, 1.58390247, 1.50473893, 1.42859455,
#          1.35578222, 1.28660115, 1.22133562, 1.16025381, 1.10360673,
#          1.05162715, 1.00452866, 0.96250481, 0.92572827, 0.89435017,
#          0.86849946, 0.84828235, 0.83378192, 0.82505776, 0.82214572]),
#   'ring_y': array([3.78405864, 3.78697068, 3.79569484, 3.81019527, 3.83041237,
#          3.85626309, 3.88764119, 3.92441772, 3.96644158, 4.01354006,
#          4.06551965, 4.12216673, 4.18324853, 4.24851407, 4.31769514,
#          4.39050747, 4.46665185, 4.54581539, 4.6276728 , 4.71188769,
#          4.79811403, 4.88599747, 4.9751769 , 5.06528584, 5.15595404,
#          5.2468089 , 5.3374771 , 5.42758605, 5.51676547, 5.60464892,
#          5.69087525, 5.77509015, 5.85694755, 5.9361111 , 6.01225548,
#          6.08506781, 6.15424888, 6.21951441, 6.28059622, 6.3372433 ,
#          6.38922288, 6.43632137, 6.47834522, 6.51512176, 6.54649985,
#          6.57235057, 6.59256768, 6.60706811, 6.61579226, 6.61870431])},
#  {'x': 8.395063610637864,
#   'y': 3.6125105469951477,
#   'time': 9.615658513632491,
#   'energy': 191.41794139058743,
#   'ring_x': array([9.81238645, 9.8094744 , 9.80075024, 9.78624982, 9.76603271,
#          9.74018199, 9.7088039 , 9.67202736, 9.63000351, 9.58290502,
#          9.53092544, 9.47427835, 9.41319655, 9.34793101, 9.27874994,
#          9.20593762, 9.12979324, 9.05062969, 8.96877229, 8.88455739,
#          8.79833106, 8.71044761, 8.62126819, 8.53115924, 8.44049104,
#          8.34963618, 8.25896798, 8.16885904, 8.07967961, 7.99179617,
#          7.90556983, 7.82135494, 7.73949753, 7.66033399, 7.5841896 ,
#          7.51137728, 7.44219621, 7.37693067, 7.31584887, 7.25920178,
#          7.2072222 , 7.16012372, 7.11809986, 7.08132332, 7.04994523,
#          7.02409451, 7.0038774 , 6.98937698, 6.98065282, 6.97774078]),
#   'ring_y': array([2.19518771, 2.19809975, 2.20682391, 2.22132434, 2.24154145,
#          2.26739217, 2.29877026, 2.3355468 , 2.37757065, 2.42466914,
#          2.47664872, 2.5332958 , 2.59437761, 2.65964314, 2.72882421,
#          2.80163654, 2.87778092, 2.95694447, 3.03880187, 3.12301677,
#          3.2092431 , 3.29712655, 3.38630597, 3.47641492, 3.56708311,
#          3.65793798, 3.74860617, 3.83871512, 3.92789455, 4.01577799,
#          4.10200432, 4.18621922, 4.26807663, 4.34724017, 4.42338455,
#          4.49619688, 4.56537795, 4.63064348, 4.69172529, 4.74837237,
#          4.80035196, 4.84745044, 4.8894743 , 4.92625083, 4.95762893,
#          4.98347964, 5.00369675, 5.01819718, 5.02692134, 5.02983338])},
#  {'x': 8.391578323242777,
#   'y': 1.4575529109158514,
#   'time': 6.697046225881362,
#   'energy': 278.48465945940325,
#   'ring_x': array([9.80890116, 9.80598912, 9.79726496, 9.78276453, 9.76254742,
#          9.7366967 , 9.70531861, 9.66854207, 9.62651822, 9.57941973,
#          9.52744015, 9.47079307, 9.40971126, 9.34444573, 9.27526466,
#          9.20245233, 9.12630795, 9.0471444 , 8.965287  , 8.8810721 ,
#          8.79484577, 8.70696232, 8.6177829 , 8.52767395, 8.43700576,
#          8.34615089, 8.2554827 , 8.16537375, 8.07619432, 7.98831088,
#          7.90208455, 7.81786965, 7.73601224, 7.6568487 , 7.58070432,
#          7.50789199, 7.43871092, 7.37344539, 7.31236358, 7.2557165 ,
#          7.20373691, 7.15663843, 7.11461457, 7.07783804, 7.04645994,
#          7.02060923, 7.00039212, 6.98589169, 6.97716753, 6.97425549]),
#   'ring_y': array([0.04023008, 0.04314212, 0.05186628, 0.0663667 , 0.08658381,
#          0.11243453, 0.14381262, 0.18058916, 0.22261302, 0.2697115 ,
#          0.32169108, 0.37833817, 0.43941997, 0.50468551, 0.57386658,
#          0.6466789 , 0.72282329, 0.80198683, 0.88384424, 0.96805913,
#          1.05428547, 1.14216891, 1.23134834, 1.32145728, 1.41212548,
#          1.50298034, 1.59364854, 1.68375749, 1.77293691, 1.86082036,
#          1.94704669, 2.03126159, 2.11311899, 2.19228254, 2.26842692,
#          2.34123924, 2.41042031, 2.47568585, 2.53676766, 2.59341474,
#          2.64539432, 2.69249281, 2.73451666, 2.7712932 , 2.80267129,
#          2.82852201, 2.84873912, 2.86323954, 2.8719637 , 2.87487575])},
#  {'x': 0.9721096774316685,
#   'y': 1.7009760163326357,
#   'time': 3.59889054032779,
#   'energy': 539.9496429974819,
#   'ring_x': array([ 2.38943251,  2.38652047,  2.37779631,  2.36329588,  2.34307877,
#           2.31722806,  2.28584996,  2.24907343,  2.20704957,  2.15995109,
#           2.1079715 ,  2.05132442,  1.99024261,  1.92497708,  1.85579601,
#           1.78298368,  1.7068393 ,  1.62767576,  1.54581835,  1.46160346,
#           1.37537712,  1.28749368,  1.19831425,  1.1082053 ,  1.01753711,
#           0.92668224,  0.83601405,  0.7459051 ,  0.65672568,  0.56884223,
#           0.4826159 ,  0.398401  ,  0.3165436 ,  0.23738005,  0.16123567,
#           0.08842334,  0.01924227, -0.04602326, -0.10710507, -0.16375215,
#          -0.21573173, -0.26283022, -0.30485407, -0.34163061, -0.3730087 ,
#          -0.39885942, -0.41907653, -0.43357696, -0.44230112, -0.44521316]),
#   'ring_y': array([0.28365318, 0.28656522, 0.29528938, 0.30978981, 0.33000692,
#          0.35585763, 0.38723573, 0.42401227, 0.46603612, 0.51313461,
#          0.56511419, 0.62176127, 0.68284308, 0.74810861, 0.81728968,
#          0.89010201, 0.96624639, 1.04540994, 1.12726734, 1.21148224,
#          1.29770857, 1.38559202, 1.47477144, 1.56488039, 1.65554858,
#          1.74640345, 1.83707164, 1.92718059, 2.01636002, 2.10424346,
#          2.19046979, 2.27468469, 2.3565421 , 2.43570564, 2.51185002,
#          2.58466235, 2.65384342, 2.71910895, 2.78019076, 2.83683784,
#          2.88881742, 2.93591591, 2.97793977, 3.0147163 , 3.0460944 ,
#          3.07194511, 3.09216222, 3.10666265, 3.11538681, 3.11829885])}]

# %%
calo.clear()
calo.draw()

# %%
for i in range(0, 100):
    p = csi.Particle(e_df=df['energy'])
    calo.impact(p)

# %%
calo.draw()

# %%
calo.xtalGrid
# Out:
# [[<calospliland.Xtal at 0x7f31126ed810>,
#   <calospliland.Xtal at 0x7f311247b850>,
#   <calospliland.Xtal at 0x7f3112479690>,
#   <calospliland.Xtal at 0x7f31126c0ed0>,
#   <calospliland.Xtal at 0x7f31125154d0>,
#   <calospliland.Xtal at 0x7f31126cba10>],
#  [<calospliland.Xtal at 0x7f31126c01d0>,
#   <calospliland.Xtal at 0x7f311248cb50>,
#   <calospliland.Xtal at 0x7f31126cb310>,
#   <calospliland.Xtal at 0x7f31126c0fd0>,
#   <calospliland.Xtal at 0x7f31180c0c50>,
#   <calospliland.Xtal at 0x7f31126cb450>],
#  [<calospliland.Xtal at 0x7f31124dd910>,
#   <calospliland.Xtal at 0x7f31180c09d0>,
#   <calospliland.Xtal at 0x7f31126c0b50>,
#   <calospliland.Xtal at 0x7f31126f9cd0>,
#   <calospliland.Xtal at 0x7f31126ed790>,
#   <calospliland.Xtal at 0x7f31126c0590>],
#  [<calospliland.Xtal at 0x7f31126f9ad0>,
#   <calospliland.Xtal at 0x7f31126edc50>,
#   <calospliland.Xtal at 0x7f31126c0c50>,
#   <calospliland.Xtal at 0x7f31126f9850>,
#   <calospliland.Xtal at 0x7f31126ed450>,
#   <calospliland.Xtal at 0x7f31180c0250>],
#  [<calospliland.Xtal at 0x7f31126cb490>,
#   <calospliland.Xtal at 0x7f31126eda10>,
#   <calospliland.Xtal at 0x7f31126c0a10>,
#   <calospliland.Xtal at 0x7f31126cb390>,
#   <calospliland.Xtal at 0x7f31126ed3d0>,
#   <calospliland.Xtal at 0x7f31180dcfd0>],
#  [<calospliland.Xtal at 0x7f3112479d50>,
#   <calospliland.Xtal at 0x7f31126edf10>,
#   <calospliland.Xtal at 0x7f31180dc850>,
#   <calospliland.Xtal at 0x7f31124798d0>,
#   <calospliland.Xtal at 0x7f31126cbcd0>,
#   <calospliland.Xtal at 0x7f3112515550>],
#  [<calospliland.Xtal at 0x7f31126c09d0>,
#   <calospliland.Xtal at 0x7f31180dc6d0>,
#   <calospliland.Xtal at 0x7f31180c07d0>,
#   <calospliland.Xtal at 0x7f31124795d0>,
#   <calospliland.Xtal at 0x7f31180dccd0>,
#   <calospliland.Xtal at 0x7f31126ed990>],
#  [<calospliland.Xtal at 0x7f31126c0490>,
#   <calospliland.Xtal at 0x7f31126ed5d0>,
#   <calospliland.Xtal at 0x7f31126c0890>,
#   <calospliland.Xtal at 0x7f31126edc10>,
#   <calospliland.Xtal at 0x7f31180c0090>,
#   <calospliland.Xtal at 0x7f31126cb8d0>],
#  [<calospliland.Xtal at 0x7f3112479c90>,
#   <calospliland.Xtal at 0x7f31126cbd50>,
#   <calospliland.Xtal at 0x7f3112479410>,
#   <calospliland.Xtal at 0x7f31126cbad0>,
#   <calospliland.Xtal at 0x7f3112479710>,
#   <calospliland.Xtal at 0x7f31126cbb10>]]
